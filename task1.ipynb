# %% [markdown]
# # Assignment 2: Milestone I Natural Language Processing
# ## Task 1. Basic Text Pre-processing
# #### Student Name: Nguyen Duc Quang
# #### Student ID: 3927198
#
# Date: 01 Oct 2023
#
# Version: 1.0
#
# Environment: Python 3 and Jupyter notebook
#
# Libraries used:
# * re
# * nltk
# * sklearn
# * itertools
#
# ## Introduction
# This notebook's purpose is to demonstrate the process of basic text pre-processing, which takes job descriptions as input and output the processed file of the text, and the vocabulary file of the file collection.

# %% [markdown]
# ## Importing libraries

# %%
# Code to import libraries as you need in this assessment, e.g.,
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from nltk.probability import *
from sklearn.datasets import load_files
import re
from itertools import chain

# %% [markdown]
# ### 1.1 Examining and loading data

# %% [markdown]
# #### Load job data

# %%
# Load job data
job_data = load_files(r"data").data
# Examine 1 job text
job_data[0]
# Out:
# b'Title: Finance / Accounts Asst Bromley to ****k\nWebindex: 68997528\nCompany: First Recruitment Services\nDescription: Accountant (partqualified) to **** p.a. South East London Our client, a successful manufacturing company has an immediate requirement for an Accountant for permanent role in their modern offices in South East London. The Role: Credit Control Purchase / Sales Ledger Daily collection of debts by phone, letter and email. Handling of ledger accounts Handling disputed accounts and negotiating payment terms Allocating of cash and reconciliation of accounts Adhoc administration duties within the business The Person The ideal candidate will have previous experience in a Credit Control capacity, you will possess exceptional customer service and communication skills together with IT proficiency. You will need to be a part or fully qualified Accountant to be considered for this role'

# %%
len(job_data)
# Out:
# 776

# %% [markdown]
# There are a total of 776 articles in total. It loos like each of them needs decoding beforehand.

# %% [markdown]
# #### Load stopwords

# %%
# Loading stopwords into a list
with open('./stopwords_en.txt', 'r') as f:
    stw = (f.read().split('\n'))
# Showing stopwords
stw
# Out:
# ['a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  "c'mon",
#  "c's",
#  'came',
#  'can',
#  "can't",
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  "couldn't",
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'described',
#  'despite',
#  'did',
#  "didn't",
#  'different',
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he's",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'knows',
#  'known',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  "let's",
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'mainly',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'my',
#  'myself',
#  'n',
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'obviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possible',
#  'presumably',
#  'probably',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonably',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'she',
#  'should',
#  "shouldn't",
#  'since',
#  'six',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'sub',
#  'such',
#  'sup',
#  'sure',
#  't',
#  "t's",
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that's",
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  "there's",
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  "wasn't",
#  'way',
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'welcome',
#  'well',
#  'went',
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  "where's",
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  "who's",
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  "won't",
#  'wonder',
#  'would',
#  'would',
#  "wouldn't",
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero']

# %% [markdown]
# ### 1.2 Pre-processing data

# %% [markdown]
# #### Tokenize job texts

# %%
# Function to remove stopwords and words that are shorter than 2 characters
def remove_words(word_list):
    # Create a new list to append valid words to
    new_list = list()
    # Loop through original list
    for word in word_list:
        if word in stw: # Ignore word to new list if word is stopword
            continue
        if len(word) < 2 : # Ignore word to new list if word is shorter than 2 characters
            continue
        new_list.append(word) # Append word to new list
    return new_list

# %%
# Function to tokenize job articles
def tokenize_article(job_txt):
    job_txt = job_txt.decode('utf-8') # Decode job text
    
    title = re.fullmatch('Title: (.+)', job_txt.split('\n')[0]).group(1) # Extract the title

    web_index = re.fullmatch('Webindex: (.+)', job_txt.split('\n')[1]).group(1) # Extract the webindex

    job_descr = re.fullmatch('Description: (.+)', job_txt.split('\n')[-1]).group(1) # Extract the description

    # Create tokenizer
    pattern = r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?"
    tokenizer = RegexpTokenizer(pattern)

    # Process job descriptions
    job_descr = job_descr.lower() # normalize description to lowercase
    sentences = sent_tokenize(job_descr) # Sentence segmentation
    
    tks = [] # Create a list to put tokens (words) in
    for sen in sentences:
        tks.extend(tokenizer.tokenize(sen)) # For each sentence tokenize it then put the list of words in tks

    tks = remove_words(tks) # Remove stopwords and words that are shorter than 2 characters

    # Process job titles 
    title = title.lower() # normalize title to lowercase
    title = tokenizer.tokenize(title) # Tokenize title
    title = remove_words(title) # Remove stopwords and words that are shorter than 2 characters

    # Return webindex, tokenized description, and title
    return [web_index, tks, title]

# %%
# Extract the tokenized titles
titles = [tokenize_article(job_txt)[2] for job_txt in job_data]

# %%
# Extract the webindexes
web_indexes = [tokenize_article(job_txt)[0] for job_txt in job_data]

# %%
# Extract the tokenized job articles
tokenize_articles = [tokenize_article(job_txt)[1] for job_txt in job_data]

# %%
tokenize_articles
# Out:
# [['accountant',
#   'partqualified',
#   'south',
#   'east',
#   'london',
#   'client',
#   'successful',
#   'manufacturing',
#   'company',
#   'requirement',
#   'accountant',
#   'permanent',
#   'role',
#   'modern',
#   'offices',
#   'south',
#   'east',
#   'london',
#   'role',
#   'credit',
#   'control',
#   'purchase',
#   'sales',
#   'ledger',
#   'daily',
#   'collection',
#   'debts',
#   'phone',
#   'letter',
#   'email',
#   'handling',
#   'ledger',
#   'accounts',
#   'handling',
#   'disputed',
#   'accounts',
#   'negotiating',
#   'payment',
#   'terms',
#   'allocating',
#   'cash',
#   'reconciliation',
#   'accounts',
#   'adhoc',
#   'administration',
#   'duties',
#   'business',
#   'person',
#   'ideal',
#   'candidate',
#   'previous',
#   'experience',
#   'credit',
#   'control',
#   'capacity',
#   'possess',
#   'exceptional',
#   'customer',
#   'service',
#   'communication',
#   'skills',
#   'proficiency',
#   'part',
#   'fully',
#   'qualified',
#   'accountant',
#   'considered',
#   'role'],
#  ['leading',
#   'hedge',
#   'funds',
#   'london',
#   'recruiting',
#   'fund',
#   'accountant',
#   'join',
#   'team',
#   'role',
#   'paying',
#   'outstanding',
#   'benefits',
#   'based',
#   'west',
#   'end',
#   'role',
#   'report',
#   'head',
#   'fund',
#   'accounting',
#   'work',
#   'number',
#   'fund',
#   'accountants',
#   'senior',
#   'fund',
#   'accountants',
#   'successful',
#   'candidate',
#   'responsible',
#   'fund',
#   'accounting',
#   'number',
#   'hedge',
#   'funds',
#   'dealing',
#   'equities',
#   'equity',
#   'related',
#   'products',
#   'role',
#   'involves',
#   'aspects',
#   'fund',
#   'accounting',
#   'preparation',
#   'journal',
#   'voucher',
#   'entries',
#   'nav',
#   'control',
#   'part',
#   'nav',
#   'review',
#   'fund',
#   'accountant',
#   'reviews',
#   'cash',
#   'securities',
#   'reconciliation',
#   'trade',
#   'input',
#   'pricing',
#   'fluctuations',
#   'financial',
#   'statements'],
#  ['exciting',
#   'opportunity',
#   'arisen',
#   'join',
#   'establish',
#   'provider',
#   'elderly',
#   'care',
#   'services',
#   'role',
#   'deputy',
#   'home',
#   'manager',
#   'support',
#   'home',
#   'manager',
#   'day',
#   'day',
#   'running',
#   'home',
#   'passion',
#   'working',
#   'care',
#   'sector',
#   'proven',
#   'experience',
#   'role',
#   'job',
#   'description',
#   'assist',
#   'registered',
#   'manager',
#   'management',
#   'home',
#   'responsibility',
#   'home',
#   'absence',
#   'registered',
#   'manager',
#   'job',
#   'requirements',
#   'ensure',
#   'high',
#   'standards',
#   'care',
#   'delivered',
#   'meet',
#   'individual',
#   'residents',
#   'ensure',
#   'healthcare',
#   'residents',
#   'met',
#   'liaising',
#   'gp',
#   'district',
#   'nurses',
#   'chiropodists',
#   'supervision',
#   'registered',
#   'manager',
#   'lead',
#   'manage',
#   'develop',
#   'work',
#   'staff',
#   'team',
#   'assist',
#   'registered',
#   'manager',
#   'management',
#   'home',
#   'responsibility',
#   'running',
#   'home',
#   'absence',
#   'registered',
#   'manager',
#   'skills',
#   'qualifications',
#   'nvq',
#   'level',
#   'care',
#   'experience',
#   'working',
#   'residential',
#   'home',
#   'experience',
#   'working',
#   'older',
#   'people',
#   'supervisory',
#   'experience',
#   'flexible',
#   'work',
#   'shift',
#   'pattern',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'deputyhomemanager',
#   'job'],
#  ['onetwotrade',
#   'expanding',
#   'sales',
#   'team',
#   'recruiting',
#   'junior',
#   'trainee',
#   'brokers',
#   'city',
#   'london',
#   'trading',
#   'floor',
#   'trainee',
#   'brokers',
#   'senior',
#   'brokers',
#   'open',
#   'close',
#   'business',
#   'clients',
#   'company',
#   'required',
#   'contact',
#   'clients',
#   'worldwide',
#   'candidates',
#   'demonstrate',
#   'structured',
#   'sales',
#   'approach',
#   'show',
#   'genuine',
#   'interest',
#   'finance',
#   'investments',
#   'manage',
#   'portfolio',
#   'clients',
#   'support',
#   'trading',
#   'activities',
#   'cold',
#   'calling',
#   'require',
#   'ambitious',
#   'genuinely',
#   'dynamic',
#   'sales',
#   'people'],
#  ['rgn',
#   'nurses',
#   'hospitals',
#   'fulltime',
#   'part',
#   'timehours',
#   'swiis',
#   'benefits',
#   'hour',
#   'dependent',
#   'banding',
#   'bonus',
#   'hours',
#   'referafriend',
#   'bonus',
#   'free',
#   'crb',
#   'free',
#   'immunisation',
#   'free',
#   'uniform',
#   'free',
#   'training',
#   'ongoing',
#   'professional',
#   'development',
#   'excellent',
#   'outofhours',
#   'management',
#   'support',
#   'swiis',
#   'urgently',
#   'requires',
#   'experienced',
#   'rgns',
#   'hospital',
#   'roles',
#   'penarth',
#   'temporary',
#   'positions',
#   'range',
#   'adhoc',
#   'shifts',
#   'short',
#   'longerterm',
#   'projects',
#   'requirements',
#   'year',
#   'paid',
#   'postqualification',
#   'nursing',
#   'experience',
#   'relevant',
#   'setting',
#   'understanding',
#   'knowledge',
#   'issues',
#   'faced',
#   'service',
#   'users',
#   'commitment',
#   'care',
#   'wellbeing',
#   'service',
#   'users',
#   'dedication',
#   'continued',
#   'professional',
#   'personal',
#   'development',
#   'skills',
#   'successful',
#   'role',
#   'submit',
#   'comprehensive',
#   'uptodate',
#   'cv',
#   'detailing',
#   'full',
#   'employment',
#   'study',
#   'history',
#   'incomplete',
#   'cvs',
#   'result',
#   'delays',
#   'processing',
#   'registration',
#   'swiis',
#   'employment',
#   'business',
#   'interim',
#   'contract',
#   'temporary',
#   'recruitment',
#   'acts',
#   'employment',
#   'agency',
#   'relation',
#   'permanent',
#   'vacancies',
#   'swiis',
#   'equal',
#   'opportunities',
#   'employer',
#   'due',
#   'volume',
#   'applicants',
#   'received',
#   'response',
#   'days',
#   'assume',
#   'successful',
#   'application',
#   'terms',
#   'conditions',
#   'apply',
#   'bonuses',
#   'apply',
#   'qualified',
#   'nurses'],
#  ['production',
#   'coordinator',
#   'sandbach',
#   'salary',
#   'pound',
#   'ndash',
#   'client',
#   'rsquo',
#   'experts',
#   'supplying',
#   'tailored',
#   'refrigeration',
#   'control',
#   'solutions',
#   'niche',
#   'markets',
#   'supermarkets',
#   'industrial',
#   'refrigeration',
#   'plants',
#   'client',
#   'established',
#   'company',
#   'years',
#   'contracting',
#   'past',
#   'years',
#   'set',
#   'expand',
#   'nbsp',
#   'nbsp',
#   'due',
#   'restructuring',
#   'client',
#   'production',
#   'coordinator',
#   'join',
#   'small',
#   'friendly',
#   'team',
#   'based',
#   'sandbach',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'production',
#   'coordinator',
#   'ndash',
#   'role',
#   'requirements',
#   'successful',
#   'candidate',
#   'manage',
#   'administrative',
#   'tasks',
#   'relating',
#   'production',
#   'activities',
#   'meet',
#   'company',
#   'targets',
#   'order',
#   'input',
#   'company',
#   'crm',
#   'system',
#   'nbsp',
#   'include',
#   'regular',
#   'telesales',
#   'contact',
#   'build',
#   'strong',
#   'working',
#   'relationships',
#   'clients',
#   'suppliers',
#   'raising',
#   'purchase',
#   'orders',
#   'suppliers',
#   'prioritising',
#   'work',
#   'load',
#   'answering',
#   'client',
#   'queries',
#   'arriving',
#   'email',
#   'telephone',
#   'facsimile',
#   'internal',
#   'external',
#   'research',
#   'retrieve',
#   'information',
#   'awareness',
#   'stock',
#   'control',
#   'procedures',
#   'assist',
#   'stock',
#   'audits',
#   'perform',
#   'clerical',
#   'duties',
#   'needed',
#   'filing',
#   'photocopying',
#   'collating',
#   'ability',
#   'questions',
#   'ascertain',
#   'potential',
#   "customer's",
#   'experience',
#   'maintaining',
#   'customer',
#   'relationship',
#   'management',
#   'software',
#   'excel',
#   'spread',
#   'sheets',
#   'general',
#   'reporting',
#   'preparation',
#   'customer',
#   'orders',
#   'arrange',
#   'national',
#   'international',
#   'courier',
#   'shipments',
#   'manage',
#   'escalate',
#   'delivery',
#   'issues',
#   'returns',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'ensure',
#   'internal',
#   'files',
#   'records',
#   'updated',
#   'production',
#   'coordinator',
#   'ndash',
#   'candidate',
#   'ideal',
#   'candidate',
#   'demonstrate',
#   'ability',
#   'maintain',
#   'confidentiality',
#   'times',
#   'ability',
#   'questions',
#   'ascertain',
#   'potential',
#   "customer's",
#   'experience',
#   'maintaining',
#   'customer',
#   'relationship',
#   'management',
#   'crm',
#   'stock',
#   'control',
#   'software',
#   'demonstrate',
#   'technical',
#   'knowledge',
#   'electronic',
#   'components',
#   'basic',
#   'understanding',
#   'knowledge',
#   'outlook',
#   'windows',
#   'xp',
#   'office',
#   'solvitt',
#   'excellent',
#   'verbal',
#   'communication',
#   'listening',
#   'skills',
#   'ability',
#   'express',
#   'thoughts',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'nbsp',
#   'demonstrate',
#   'positive',
#   'attitude',
#   'enthusiasm',
#   'goaloriented',
#   'approach',
#   'achievement',
#   'ability',
#   'team',
#   'player',
#   'car',
#   'owner',
#   'full',
#   'clean',
#   'driving',
#   'license',
#   'occasional',
#   'local',
#   'travel',
#   'requirements',
#   'apply',
#   'send',
#   'detailed',
#   'cv',
#   'blocked',
#   'email',
#   'nbsp'],
#  ['job',
#   'reference',
#   'vac',
#   'job',
#   'title',
#   'scrub',
#   'nurse',
#   'location',
#   'norwich',
#   'norfolk',
#   'salary',
#   'annum',
#   'hours',
#   'full',
#   'time',
#   'hospital',
#   'client',
#   'largest',
#   'providers',
#   'private',
#   'healthcare',
#   'uk',
#   'hospitals',
#   'norwich',
#   'hospital',
#   'offers',
#   'private',
#   'healthcare',
#   'local',
#   'residents',
#   'hospital',
#   'suite',
#   'theatres',
#   'equipped',
#   'laminar',
#   'flow',
#   'covers',
#   'wide',
#   'range',
#   'surgical',
#   'specialities',
#   'includes',
#   'dedicated',
#   'sterile',
#   'services',
#   'department',
#   'role',
#   'undertaking',
#   'wide',
#   'range',
#   'surgical',
#   'specialities',
#   'position',
#   'presents',
#   'opportunity',
#   'broaden',
#   'skills',
#   'whilst',
#   'working',
#   'modern',
#   'environment',
#   'friendly',
#   'enthusiastic',
#   'team',
#   'experience',
#   'working',
#   'theatre',
#   'environment',
#   'essential',
#   'preferably',
#   'including',
#   'major',
#   'ortho',
#   'ophthalmic',
#   'general',
#   'gynae',
#   'work',
#   'main',
#   'responsibilities',
#   'provide',
#   'exemplary',
#   'planned',
#   'care',
#   'patients',
#   'perioperative',
#   'area',
#   'assist',
#   'management',
#   'organisation',
#   'care',
#   'provision',
#   'operating',
#   'theatre',
#   'qualifications',
#   'training',
#   'essential',
#   'registered',
#   'nurse',
#   'hpc',
#   'experience',
#   'essential',
#   'working',
#   'teams',
#   'minimum',
#   'supervision',
#   'experience',
#   'caring',
#   'role',
#   'desirable',
#   'experience',
#   'applying',
#   'clinical',
#   'reasoning',
#   'skills',
#   'range',
#   'complex',
#   'varied',
#   'patient',
#   'case',
#   'mixes',
#   'apply',
#   'post',
#   'email',
#   'cv',
#   'echadwickeclypserecruitment',
#   'uk',
#   'call'],
#  ['client',
#   'recruit',
#   'experienced',
#   'sales',
#   'purchase',
#   'ledger',
#   'clerk',
#   'covering',
#   'maternity',
#   'february',
#   'mid',
#   'year',
#   'ideal',
#   'candidate',
#   'immediately',
#   'duties',
#   'responsibilities',
#   'limited',
#   'sales',
#   'ledger',
#   'input',
#   'cheques',
#   'bacs',
#   'received',
#   'sage',
#   'accurately',
#   'reconcile',
#   'remittances',
#   'actual',
#   'receipts',
#   'prepare',
#   'banking',
#   'book',
#   'responsible',
#   'ensure',
#   'credit',
#   'control',
#   'professional',
#   'timely',
#   'manner',
#   'send',
#   'customer',
#   'statements',
#   'monthly',
#   'basis',
#   'managing',
#   'aged',
#   'debtors',
#   'report',
#   'purchase',
#   'ledger',
#   'prepare',
#   'payment',
#   'run',
#   'ensuring',
#   'invoices',
#   'due',
#   'processed',
#   'duplicates',
#   'log',
#   'payments',
#   'sage',
#   'cheques',
#   'bacs',
#   'chaps',
#   'deal',
#   'account',
#   'payable',
#   'queries',
#   'managing',
#   'aged',
#   'creditors',
#   'report',
#   'skills',
#   'requirements',
#   'years',
#   'experience',
#   'experience',
#   'systems',
#   'invoicing',
#   'good',
#   'understanding',
#   'currencies',
#   'computer',
#   'literate',
#   'office',
#   'outlook',
#   'word',
#   'excel',
#   'sage',
#   'experience',
#   'preferred',
#   'minimum',
#   'sage',
#   'ability',
#   'work',
#   'tight',
#   'deadlines',
#   'errors',
#   'good',
#   'numeracy',
#   'skills',
#   'good',
#   'communication',
#   'skills',
#   'organised',
#   'efficient',
#   'good',
#   'attention',
#   'detail',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'salespurchaseledgerclerkmaternitycover',
#   'job'],
#  ['client',
#   'leading',
#   'recruitment',
#   'company',
#   'based',
#   'west',
#   'suffolk',
#   'north',
#   'essex',
#   'cambridgeshire',
#   'border',
#   'embarking',
#   'expansion',
#   'programme',
#   'actively',
#   'recruit',
#   'tenacious',
#   'passionate',
#   'sales',
#   'consultant',
#   'role',
#   'faint',
#   'hearted',
#   'drive',
#   'determination',
#   'commitment',
#   'succeed',
#   'extremely',
#   'competitive',
#   'sector',
#   'territory',
#   'span',
#   'counties',
#   'focus',
#   'cambridge',
#   'newmarket',
#   'haverhill',
#   'role',
#   'office',
#   'based',
#   'field',
#   'based',
#   'involve',
#   'business',
#   'business',
#   'telesales',
#   'face',
#   'face',
#   'sales',
#   'targeted',
#   'making',
#   'appointments',
#   'team',
#   'ensuring',
#   'activity',
#   'accurately',
#   'recorded',
#   'person',
#   'recruit',
#   'sales',
#   'experience',
#   'proven',
#   'track',
#   'record',
#   'hunger',
#   'succeed',
#   'challenge',
#   'ahead',
#   'maintain',
#   'positive',
#   'attitude',
#   'times',
#   'recruitment',
#   'experience',
#   'advantage',
#   'means',
#   'essential',
#   'person',
#   'training',
#   'sector',
#   'transport',
#   'preferred',
#   'offer',
#   'competitive',
#   'basic',
#   'salary',
#   'excellent',
#   'bonus',
#   'structure',
#   'career',
#   'progression',
#   'company',
#   'possibility',
#   'interviews',
#   'place',
#   'short',
#   'listing',
#   'process',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'recruitmentsalesexecutive',
#   'job'],
#  ['position',
#   'business',
#   'development',
#   'executive',
#   'field',
#   'sales',
#   'dartford',
#   'salary',
#   'kbasic',
#   'ote',
#   'car',
#   'bens',
#   'location',
#   'dartford',
#   'territory',
#   'da',
#   'se',
#   'br',
#   'hungry',
#   'ambitious',
#   'business',
#   'sales',
#   'professional',
#   'company',
#   'firmly',
#   'established',
#   'industry',
#   'people',
#   'proven',
#   'success',
#   'business',
#   'excellent',
#   'customer',
#   'service',
#   'focus',
#   'opportunity',
#   'build',
#   'long',
#   'term',
#   'career',
#   'part',
#   'continued',
#   'success',
#   'representing',
#   'premium',
#   'service',
#   'providers',
#   'impressive',
#   'range',
#   'environmental',
#   'hygiene',
#   'services',
#   'solutions',
#   'role',
#   'generate',
#   'business',
#   'opportunities',
#   'south',
#   'east',
#   'london',
#   'area',
#   'selling',
#   'sme',
#   'sector',
#   'selling',
#   'contractual',
#   'sale',
#   'environmental',
#   'sector',
#   'emphasis',
#   'service',
#   'solution',
#   'successful',
#   'candidate',
#   'proven',
#   'successful',
#   'business',
#   'sales',
#   'track',
#   'record',
#   'months',
#   'years',
#   'field',
#   'sales',
#   'experience',
#   'polished',
#   'articulate',
#   'communicator',
#   'ideally',
#   'service',
#   'led',
#   'sector',
#   'experience',
#   'contractual',
#   'sale',
#   'advantageous',
#   'driven',
#   'aspects',
#   'role',
#   'planning',
#   'organizing',
#   'week',
#   'cold',
#   'calling',
#   'potential',
#   'customers',
#   'adapt',
#   'clients',
#   'personalities',
#   'build',
#   'business',
#   'development',
#   'background',
#   'service',
#   'related',
#   'industries',
#   'cleaning',
#   'logistics',
#   'environmental',
#   'services',
#   'contract',
#   'sales',
#   'advantageous',
#   'working',
#   'role',
#   'requires',
#   'round',
#   'sales',
#   'professional',
#   'drive',
#   'energy',
#   'ideal',
#   'role',
#   'key',
#   'words',
#   'recycling',
#   'washroom',
#   'services',
#   'pest',
#   'control',
#   'contract',
#   'hire',
#   'business',
#   'development',
#   'field',
#   'sales',
#   'cold',
#   'calling',
#   'business',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'businessdevelopmentexecutivefieldsalesdartford',
#   'job'],
#  ['client',
#   'based',
#   'eastleigh',
#   'investments',
#   'treasury',
#   'controller',
#   'join',
#   'team',
#   'duties',
#   'include',
#   'responsibility',
#   'transactional',
#   'management',
#   'analysis',
#   'oversight',
#   'company',
#   'investment',
#   'portfolio',
#   'including',
#   'compliance',
#   'relevant',
#   'sections',
#   'relevant',
#   'policies',
#   'ensure',
#   'working',
#   'capital',
#   'liquid',
#   'resources',
#   'cashflow',
#   'managed',
#   'efficiently',
#   'deliver',
#   'consistently',
#   'relevant',
#   'kpis',
#   'kris',
#   'analysing',
#   'shortfalls',
#   'putting',
#   'action',
#   'plans',
#   'place',
#   'remediate',
#   'process',
#   'issues',
#   'manage',
#   'day',
#   'day',
#   'relationships',
#   'company',
#   'outsourced',
#   'investment',
#   'managers',
#   'custodians',
#   'ensuring',
#   'mutual',
#   'understanding',
#   'operations',
#   'systems',
#   'developments',
#   'business',
#   'transacted',
#   'efficiently',
#   'effectively',
#   'endtoend',
#   'investment',
#   'processes',
#   'ensuring',
#   'processes',
#   'procedures',
#   'risks',
#   'controls',
#   'documented',
#   'effective',
#   'efficient',
#   'regularly',
#   'review',
#   'test',
#   'processes',
#   'controls',
#   'accordance',
#   'finance',
#   'control',
#   'risk',
#   'framework',
#   'skills',
#   'experience',
#   'ability',
#   'build',
#   'relationships',
#   'stakeholders',
#   'levels',
#   'internal',
#   'external',
#   'challenge',
#   'assumptions',
#   'positively',
#   'bring',
#   'people',
#   'journey',
#   'strong',
#   'written',
#   'communication',
#   'skills',
#   'fluent',
#   'articulate',
#   'confident',
#   'spoken',
#   'communication',
#   'understanding',
#   'investment',
#   'principles',
#   'significant',
#   'experience',
#   'practical',
#   'application',
#   'coupled',
#   'excellent',
#   'analytical',
#   'skills',
#   'strong',
#   'risks',
#   'control',
#   'awareness',
#   'required',
#   'strong',
#   'organisational',
#   'planning',
#   'skills',
#   'coupled',
#   'ability',
#   'drive',
#   'solutions',
#   'proactive',
#   'highly',
#   'motivated',
#   'change',
#   'orientated',
#   'identify',
#   'obstacles',
#   'clear',
#   'effectively',
#   'literate',
#   'including',
#   'experience',
#   'accounting',
#   'systems',
#   'data',
#   'warehouse',
#   'architectures',
#   'desktop',
#   'systems',
#   'fluent',
#   'microsoft',
#   'excel',
#   'word',
#   'powerpoint',
#   'ability',
#   'understand',
#   'evaluate',
#   'interpret',
#   'diverse',
#   'financial',
#   'data',
#   'experience',
#   'treasury',
#   'investment',
#   'role',
#   'aca',
#   'acca',
#   'cima',
#   'qualified',
#   'equivalent',
#   'august',
#   'clarke',
#   'limited',
#   'acting',
#   'recruitment',
#   'agency',
#   'relation',
#   'role',
#   'discriminate',
#   'grounds',
#   'age',
#   'race',
#   'gender',
#   'disability',
#   'creed',
#   'sexual',
#   'orientation',
#   'comply',
#   'relevant',
#   'uk',
#   'legislation',
#   'hear',
#   'back',
#   'working',
#   'days',
#   'assume',
#   'successful',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'investmentstreasurycontroller',
#   'job'],
#  ['established',
#   'company',
#   'based',
#   'hemel',
#   'hempstead',
#   'join',
#   'payroll',
#   'team',
#   'process',
#   'payroll',
#   'european',
#   'employees',
#   'previously',
#   'worked',
#   'role',
#   'processing',
#   'european',
#   'payroll',
#   'long',
#   'term',
#   'happy',
#   'work',
#   'full',
#   'time',
#   'hours',
#   'position',
#   'monday',
#   'friday',
#   'working',
#   'pm',
#   'role',
#   'working',
#   'payroll',
#   'team',
#   'process',
#   'payroll',
#   'european',
#   'employees',
#   'temporary',
#   'permanent',
#   'position',
#   'long',
#   'term'],
#  ['engineering',
#   'assessor',
#   'instructor',
#   'south',
#   'yorkshire',
#   'depending',
#   'experience',
#   'bonus',
#   'days',
#   'holiday',
#   'bank',
#   'holidays',
#   'pension',
#   'life',
#   'assurance',
#   'engineering',
#   'assessor',
#   'engineering',
#   'instructor',
#   'challenge',
#   'company',
#   'training',
#   'company',
#   'leading',
#   'engineering',
#   'training',
#   'arena',
#   'result',
#   'extremely',
#   'successful',
#   'year',
#   'recruit',
#   'engineering',
#   'assessor',
#   'instructor',
#   'continue',
#   'successful',
#   'trend',
#   'return',
#   'expect',
#   'packages',
#   'industry',
#   'receive',
#   'ongoing',
#   'support',
#   'training',
#   'development',
#   'ensure',
#   'maintain',
#   'company',
#   'high',
#   'standards',
#   'success',
#   'role',
#   'role',
#   'delivering',
#   'engineering',
#   'apprenticeship',
#   'training',
#   'supervision',
#   'day',
#   'day',
#   'activities',
#   'operation',
#   'engineering',
#   'workshops',
#   'delivery',
#   'assessment',
#   'training',
#   'ensure',
#   'achievement',
#   'financial',
#   'targeted',
#   'workshop',
#   'activities',
#   'candidate',
#   'skills',
#   'qualifications',
#   'qualification',
#   'assessors',
#   'award',
#   'engineering',
#   'background',
#   'candidates',
#   'suitable',
#   'position',
#   'live',
#   'areas',
#   'barnsley',
#   'batley',
#   'castleford',
#   'chesterfield',
#   'dewsbury',
#   'doncaster',
#   'huddersfield',
#   'leeds',
#   'morley',
#   'pontefract',
#   'rotherham',
#   'sheffield',
#   'wakefield',
#   'additional',
#   'resources',
#   'employment',
#   'business',
#   'employment',
#   'agency',
#   'defined',
#   'conduct',
#   'employment',
#   'agencies',
#   'employment',
#   'businesses',
#   'regulations'],
#  ['client',
#   'based',
#   'outskirts',
#   'poole',
#   'dorset',
#   'recruiting',
#   'international',
#   'account',
#   'manager',
#   'join',
#   'highly',
#   'successful',
#   'manufacturing',
#   'services',
#   'organisation',
#   'international',
#   'account',
#   'manager',
#   'interface',
#   'companies',
#   'international',
#   'customers',
#   'companies',
#   'entire',
#   'service',
#   'delivery',
#   'organisation',
#   'responsibilities',
#   'varied',
#   'challenging',
#   'include',
#   'maintaining',
#   'identifying',
#   'creating',
#   'promoting',
#   'companies',
#   'international',
#   'client',
#   'base',
#   'build',
#   'relationships',
#   'levels',
#   'senior',
#   'management',
#   'operational',
#   'staff',
#   'supporting',
#   'working',
#   'closely',
#   'sales',
#   'director',
#   'pivotal',
#   'link',
#   'international',
#   'relationships',
#   'working',
#   'framework',
#   'objectives',
#   'targets',
#   'set',
#   'sales',
#   'director',
#   'initiative',
#   'support',
#   'sales',
#   'teams',
#   'enabling',
#   'targets',
#   'reached',
#   'achieved',
#   'role',
#   'require',
#   'international',
#   'travel',
#   'time',
#   'uk',
#   'head',
#   'office',
#   'ideal',
#   'candidate',
#   'strong',
#   'background',
#   'account',
#   'management',
#   'ideally',
#   'working',
#   'electronics',
#   'services',
#   'industries',
#   'worked',
#   'blue',
#   'chip',
#   'large',
#   'corporate',
#   'customers',
#   'fantastic',
#   'opportunity',
#   'develop',
#   'international',
#   'career',
#   'reputable',
#   'successful',
#   'organisation',
#   'benefits',
#   'include',
#   'car',
#   'allowance',
#   'days',
#   'holiday',
#   'parking',
#   'opportunity',
#   'make',
#   'newly',
#   'created',
#   'role'],
#  ['client',
#   'major',
#   'oil',
#   'operator',
#   'malaysia',
#   'senior',
#   'porduction',
#   'technologist',
#   'provide',
#   'technical',
#   'production',
#   'technology',
#   'expertise',
#   'satellites',
#   'susurface',
#   'team',
#   'promary',
#   'focus',
#   'satellite',
#   'project',
#   'maturation',
#   'bachelor',
#   'degree',
#   'petroleum',
#   'engineering',
#   'equivalent',
#   'minimum',
#   'yrs',
#   'production',
#   'technology',
#   'experience',
#   'oil',
#   'gas',
#   'reservior',
#   'management',
#   'field',
#   'development',
#   'planning',
#   'strong',
#   'conceptual',
#   'design',
#   'skills',
#   'subsea',
#   'systems',
#   'experience',
#   'managing',
#   'reservoir',
#   'uncertainties',
#   'risks',
#   'experience',
#   'deepwater',
#   'project',
#   'advantage'],
#  ['insurance',
#   'sales',
#   'executive',
#   'horsham',
#   'dep',
#   'horsham',
#   'established',
#   'insurance',
#   'industry',
#   'exciting',
#   'opportunity',
#   'talented',
#   'sales',
#   'professional',
#   'opening',
#   'working',
#   'insurance',
#   'sales',
#   'financial',
#   'background',
#   'ideally',
#   'key',
#   'immaculate',
#   'presentation',
#   'top',
#   'communication',
#   'skills',
#   'ideal',
#   'candidate',
#   'moved',
#   'career',
#   'stepping',
#   'stone',
#   'expect',
#   'work',
#   'day',
#   'week',
#   'customer',
#   'focused',
#   'professional',
#   'good',
#   'communicator',
#   'sell',
#   'role',
#   'initially',
#   'entail',
#   'dealing',
#   'aspects',
#   'insurance',
#   'policies',
#   'inception',
#   'midterm',
#   'renewals',
#   'claims',
#   'dealing',
#   'motor',
#   'home',
#   'travel',
#   'breakdown',
#   'insurances',
#   'sell',
#   'communicate',
#   'types',
#   'clients',
#   'phone',
#   'face',
#   'face',
#   'training',
#   'house',
#   'hands',
#   'expected',
#   'study',
#   'certificate',
#   'insurance',
#   'time',
#   'consists',
#   'exams',
#   'year',
#   'pass',
#   'client',
#   'promotes',
#   'real',
#   'career',
#   'path',
#   'individual',
#   'additional',
#   'resources',
#   'employment',
#   'business',
#   'employment',
#   'agency',
#   'defined',
#   'conduct',
#   'employment',
#   'agencies',
#   'employment',
#   'businesses',
#   'regulations'],
#  ['vehicle',
#   'purchaser',
#   'car',
#   'sales',
#   'birkenhead',
#   'southport',
#   'bonus',
#   'ote',
#   'year',
#   'summary',
#   'challenging',
#   'exciting',
#   'rewarding',
#   'opportunity',
#   'work',
#   'uk',
#   'leading',
#   'car',
#   'buying',
#   'service',
#   'vehicle',
#   'purchaser',
#   'managing',
#   'branch',
#   'business',
#   'basic',
#   'salary',
#   'open',
#   'ended',
#   'bonus',
#   'structure',
#   'offers',
#   'genuine',
#   'ote',
#   'year',
#   'role',
#   'perfect',
#   'confident',
#   'outgoing',
#   'business',
#   'minded',
#   'people',
#   'build',
#   'rapport',
#   'customers',
#   'discipline',
#   'focus',
#   'run',
#   'branch',
#   'effectively',
#   'note',
#   'experience',
#   'working',
#   'automotive',
#   'industry',
#   'essential',
#   'comprehensive',
#   'training',
#   'provided',
#   'company',
#   'leading',
#   'player',
#   'uk',
#   'car',
#   'buying',
#   'remarketing',
#   'industry',
#   'business',
#   'recognisable',
#   'distinctive',
#   'powerful',
#   'branding',
#   'established',
#   'years',
#   'ago',
#   'objective',
#   'customers',
#   'sell',
#   'car',
#   'quickly',
#   'safety',
#   'easily',
#   'ambitious',
#   'business',
#   'growing',
#   'presence',
#   'uk',
#   'role',
#   'role',
#   'remits',
#   'firstly',
#   'suggests',
#   'responsible',
#   'purchasing',
#   'vehicles',
#   'directly',
#   'customers',
#   'initially',
#   'make',
#   'enquiry',
#   'online',
#   'introductory',
#   'telephone',
#   'call',
#   'build',
#   'initial',
#   'relationship',
#   'meet',
#   'customer',
#   'branch',
#   'inspect',
#   'vehicle',
#   'excellent',
#   'customer',
#   'service',
#   'skills',
#   'work',
#   'customer',
#   'buy',
#   'car',
#   'directly',
#   'responsible',
#   'effective',
#   'professional',
#   'management',
#   'branch',
#   'managing',
#   'prioritising',
#   'workload',
#   'diary',
#   'ensuring',
#   'deliver',
#   'class',
#   'customer',
#   'experience',
#   'customer',
#   'vehicle',
#   'purchaser',
#   'responsibility',
#   'proactively',
#   'seeking',
#   'generating',
#   'customers',
#   'branch',
#   'note',
#   'experience',
#   'working',
#   'automotive',
#   'industry',
#   'essential',
#   'comprehensive',
#   'training',
#   'provided',
#   'challenging',
#   'role',
#   'feel',
#   'running',
#   'business',
#   'people',
#   'foremost',
#   'confidence',
#   'discipline',
#   'drive',
#   'determination',
#   'manage',
#   'branch',
#   'people',
#   'selfmotivation',
#   'hunger',
#   'achieve',
#   'succeed',
#   'great',
#   'business',
#   'whilst',
#   'automotive',
#   'experience',
#   'essential',
#   'essential',
#   'worked',
#   'customer',
#   'focused',
#   'environment',
#   'strong',
#   'rapport',
#   'building',
#   'customer',
#   'service',
#   'skills',
#   'engage',
#   'customers',
#   'order',
#   'sell',
#   'vehicle',
#   'important',
#   'process',
#   'driven',
#   'good',
#   'numbers',
#   'high',
#   'level',
#   'mental',
#   'agility',
#   'required',
#   'process',
#   'lots',
#   'information',
#   'quickly',
#   'feet',
#   'whilst',
#   'supported',
#   'area',
#   'manager',
#   'comfortable',
#   'working',
#   'salary',
#   'basic',
#   'bonus',
#   'year',
#   'ote',
#   'top',
#   'performers',
#   'earning',
#   'hours',
#   'days',
#   'include',
#   'saturday',
#   'sunday',
#   'weekdays',
#   'pm',
#   'saturday',
#   'pm',
#   'sunday',
#   'pm',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'vehiclepurchasercarsales',
#   'job'],
#  ['marine',
#   'engines',
#   'specialist',
#   'product',
#   'supportslough',
#   'berkshirec',
#   'annual',
#   'bonus',
#   'contributory',
#   'pension',
#   'health',
#   'scheme',
#   'travel',
#   'insurance',
#   'death',
#   'service',
#   'days',
#   'holiday',
#   'client',
#   'largest',
#   'caterpillar',
#   'dealers',
#   'world',
#   'acting',
#   'official',
#   'dealer',
#   'east',
#   'west',
#   'africa',
#   'middle',
#   'east',
#   'western',
#   'siberia',
#   'offer',
#   'customers',
#   'complete',
#   'range',
#   'power',
#   'generation',
#   'construction',
#   'mining',
#   'materials',
#   'handling',
#   'equipment',
#   'working',
#   'closely',
#   'customers',
#   'offer',
#   'aftersales',
#   'service',
#   'secondtonone',
#   'structured',
#   'support',
#   'agreements',
#   'local',
#   'parts',
#   'availability',
#   'cat',
#   'certified',
#   'engineers',
#   'opportunity',
#   'arisen',
#   'marine',
#   'engines',
#   'specialist',
#   'join',
#   'product',
#   'support',
#   'team',
#   'strong',
#   'sales',
#   'engineer',
#   'background',
#   'experience',
#   'working',
#   'marine',
#   'diesel',
#   'engine',
#   'industry',
#   'superb',
#   'opening',
#   'join',
#   'global',
#   'company',
#   'offering',
#   'excellent',
#   'progression',
#   'prospects',
#   'chance',
#   'travel',
#   'internationally',
#   'opportunity',
#   'pioneer',
#   'establish',
#   'working',
#   'practices',
#   'standards',
#   'rapidly',
#   'developing',
#   'market',
#   'sector',
#   'marine',
#   'engines',
#   'specialist',
#   'responsible',
#   'supporting',
#   'business',
#   'units',
#   'parts',
#   'service',
#   'sales',
#   'marine',
#   'customers',
#   'create',
#   'strategic',
#   'action',
#   'plans',
#   'identify',
#   'gaps',
#   'market',
#   'enhance',
#   "client's",
#   'capability',
#   'capacity',
#   'additionally',
#   'undertake',
#   'customer',
#   'visits',
#   'develop',
#   "client's",
#   'image',
#   'ensure',
#   'customers',
#   'choice',
#   'duties',
#   'include',
#   'frequently',
#   'travelling',
#   'engage',
#   'marine',
#   'customer',
#   'base',
#   'maintain',
#   'relationships',
#   'key',
#   'customers',
#   'engaging',
#   'caterpillar',
#   'industry',
#   'specialists',
#   'provide',
#   'coverage',
#   'support',
#   'marketing',
#   'plan',
#   'assistance',
#   'increasing',
#   'marine',
#   'product',
#   'support',
#   'business',
#   'reach',
#   'exceed',
#   "client's",
#   'target',
#   'considered',
#   'demonstrable',
#   'experience',
#   'working',
#   'largebore',
#   'mediumspeed',
#   'diesel',
#   'engines',
#   'marine',
#   'propulsion',
#   'systems',
#   'ideally',
#   'product',
#   'support',
#   'function',
#   'engineering',
#   'apprenticeship',
#   'qualification',
#   'diploma',
#   'degree',
#   'marine',
#   'engines',
#   'specialist',
#   'strong',
#   'team',
#   'player',
#   'mentality',
#   'ability',
#   'work',
#   'cross',
#   'functional',
#   'capacity',
#   'logical',
#   'responsible',
#   'great',
#   'reasoning',
#   'negotiation',
#   'skills',
#   'comfortable',
#   'engaging',
#   'customers',
#   'problem',
#   'solve',
#   'high',
#   'level',
#   'apply',
#   'role',
#   'marine',
#   'engines',
#   'specialist',
#   'product',
#   'support',
#   'apply',
#   'button',
#   'shown',
#   'vacancy',
#   'advertised',
#   'web',
#   'recruit',
#   'services',
#   'advertised',
#   'web',
#   'recruit',
#   'employment',
#   'agency',
#   'additional',
#   'keywords',
#   'product',
#   'support',
#   'specialist',
#   'marine',
#   'engines',
#   'product',
#   'specialist',
#   'marine',
#   'engineer',
#   'product',
#   'specialist',
#   'product',
#   'engineer',
#   'product',
#   'support',
#   'engineer',
#   'marine',
#   'engine',
#   'specialist',
#   'technical',
#   'product',
#   'specialist',
#   'product',
#   'support',
#   'manager',
#   'bonus',
#   'company',
#   'pension',
#   'healthcare',
#   'salary',
#   'annual',
#   'bonus'],
#  ['sales',
#   'manager',
#   'medical',
#   'sales',
#   'executive',
#   'medical',
#   'software',
#   'full',
#   'benefits',
#   'london',
#   'south',
#   'east',
#   'company',
#   'established',
#   'growing',
#   'rapidly',
#   'company',
#   'sells',
#   'enterprise',
#   'resource',
#   'planning',
#   'erp',
#   'software',
#   'suites',
#   'bespoke',
#   'nhs',
#   'focus',
#   'inventory',
#   'management',
#   'enabling',
#   'reduced',
#   'patient',
#   'service',
#   'level',
#   'costings',
#   'real',
#   'demonstrable',
#   'roi',
#   'selling',
#   'nhs',
#   'trusts',
#   'dealing',
#   'senior',
#   'management',
#   'procurement',
#   'departments',
#   'business',
#   'focused',
#   'role',
#   'sales',
#   'contracts',
#   'typically',
#   'worth',
#   'region',
#   'negotiated',
#   'periods',
#   'months',
#   'excellent',
#   'remuneration',
#   'package',
#   'offer',
#   'comprehensive',
#   'product',
#   'training',
#   'person',
#   'successful',
#   'sales',
#   'candidate',
#   'skills',
#   'strong',
#   'field',
#   'sales',
#   'background',
#   'demonstrable',
#   'track',
#   'record',
#   'large',
#   'sales',
#   'long',
#   'sales',
#   'cycles',
#   'knowledge',
#   'nhs',
#   'procurement',
#   'system',
#   'trusts',
#   'supply',
#   'chain',
#   'essential',
#   'degree',
#   'calibre',
#   'candidates',
#   'extensive',
#   'problem',
#   'solving',
#   'skills',
#   'huge',
#   'amounts',
#   'motivation',
#   'required',
#   'package',
#   'basic',
#   'salary',
#   'mileage',
#   'mobile',
#   'laptop',
#   'pension',
#   'days',
#   'holidays',
#   'bms',
#   'leading',
#   'recruitment',
#   'consultancy',
#   'specialising',
#   'sales',
#   'recruitment',
#   'established',
#   'bms',
#   'achieved',
#   'nationwide',
#   'presence',
#   'number',
#   'regional',
#   'centres',
#   'head',
#   'office',
#   'egham',
#   'ideally',
#   'located',
#   'service',
#   'candidates',
#   'clients',
#   'alike',
#   'london',
#   'south',
#   'east',
#   'offering',
#   'medical',
#   'sales',
#   'jobs',
#   'trainees',
#   'sales',
#   'representatives',
#   'sales',
#   'executives',
#   'nurse',
#   'advisors',
#   'area',
#   'sales',
#   'managers',
#   'territory',
#   'managers',
#   'account',
#   'managers',
#   'opportunities',
#   'corner',
#   'uk',
#   'conveniently',
#   'located',
#   'committed',
#   'meet',
#   'potentially',
#   'suitable',
#   'applicants',
#   'face',
#   'face',
#   'organisation',
#   'consists',
#   'highly',
#   'focused',
#   'teams',
#   'aimed',
#   'specific',
#   'market',
#   'sectors',
#   'enabling',
#   'deliver',
#   'service',
#   'directly',
#   'tailored',
#   'visit',
#   'website',
#   'www',
#   'bmsuk',
#   'alternatively',
#   'contact',
#   'specialist',
#   'medical',
#   'sales',
#   'consultants',
#   'oliver',
#   'fox',
#   'tom',
#   'pringle',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'salestarget',
#   'uk',
#   'jobseeking',
#   'salesmanagermedicalsalesexecutive',
#   'job'],
#  ['job',
#   'description',
#   'inspired',
#   'selections',
#   'optical',
#   'assistant',
#   'oxfordshire',
#   'business',
#   'locally',
#   'high',
#   'level',
#   'customer',
#   'service',
#   'provide',
#   'established',
#   'years',
#   'ago',
#   'provide',
#   'friendly',
#   'professional',
#   'service',
#   'highly',
#   'competitive',
#   'prices',
#   'practices',
#   'fully',
#   'qualified',
#   'dispensing',
#   'opticians',
#   'hand',
#   'members',
#   'association',
#   'british',
#   'dispensing',
#   'opticians',
#   'company',
#   'combines',
#   'service',
#   'small',
#   'independent',
#   'group',
#   'prices',
#   'compete',
#   'larger',
#   'chains',
#   'patients',
#   'enjoy',
#   'worlds',
#   'committed',
#   'principals',
#   'service',
#   'care',
#   'staff',
#   'respected',
#   'loyal',
#   'patients',
#   'information',
#   'contact',
#   'inspired',
#   'selections'],
#  ['job',
#   'title',
#   'unit',
#   'manager',
#   'reporting',
#   'registered',
#   'manager',
#   'job',
#   'purpose',
#   'manage',
#   'professional',
#   'manner',
#   'day',
#   'day',
#   'running',
#   'home',
#   'administration',
#   'clinical',
#   'policies',
#   'procedures',
#   'training',
#   'care',
#   'planning',
#   'implement',
#   'working',
#   'practices',
#   'monitors',
#   'health',
#   'welfare',
#   'home',
#   'service',
#   'users',
#   'staff',
#   'respective',
#   'environments',
#   'promote',
#   'quality',
#   'care',
#   'warm',
#   'friendly',
#   'ambience',
#   'key',
#   'result',
#   'areas',
#   'managing',
#   'work',
#   'directors',
#   'achieve',
#   'home',
#   'financial',
#   'targets',
#   'manage',
#   'home',
#   'manner',
#   'bring',
#   'home',
#   'service',
#   'users',
#   'disrepute',
#   'maintain',
#   'confidentiality',
#   'aspects',
#   'care',
#   'staff',
#   'management',
#   'ensure',
#   'home',
#   'policies',
#   'procedures',
#   'implemented',
#   'staff',
#   'inform',
#   'registered',
#   'manager',
#   'immediately',
#   'difficulty',
#   'event',
#   'occurs',
#   'managing',
#   'support',
#   'delegate',
#   'responsibility',
#   'effectively',
#   'legal',
#   'boundaries',
#   'ensure',
#   'clinical',
#   'standards',
#   'audits',
#   'good',
#   'practice',
#   'maintained',
#   'home',
#   'nursing',
#   'duties',
#   'perform',
#   'nursing',
#   'duties',
#   'reflect',
#   'current',
#   'practice',
#   'abreast',
#   'latest',
#   'developments',
#   'inform',
#   'registered',
#   'manager',
#   'nursing',
#   'medical',
#   'matters',
#   'affecting',
#   'service',
#   'user',
#   'care',
#   'assist',
#   'service',
#   'users',
#   'personal',
#   'care',
#   'includes',
#   'bath',
#   'bed',
#   'bath',
#   'shower',
#   'feet',
#   'nail',
#   'care',
#   'hair',
#   'care',
#   'shaving',
#   'mouth',
#   'care',
#   'denture',
#   'care',
#   'toileting',
#   'daily',
#   'activities',
#   'individual',
#   'care',
#   'plans',
#   'including',
#   'tidying',
#   'bed',
#   'room',
#   'assist',
#   'clients',
#   'psychological',
#   'includes',
#   'talking',
#   'listening',
#   'excursions',
#   'liaising',
#   'family',
#   'assisting',
#   'hobbies',
#   'recreation',
#   'activities',
#   'care',
#   'service',
#   'user',
#   'individual',
#   'maintain',
#   'high',
#   'level',
#   'care',
#   'condition',
#   'ensuring',
#   'physical',
#   'comfort',
#   'dignity',
#   'met',
#   'care',
#   'service',
#   'user',
#   'end',
#   'life',
#   'respectful',
#   'dignified',
#   'manner',
#   'administer',
#   'medication',
#   'strictly',
#   'accordance',
#   'drug',
#   'administration',
#   'policy',
#   'nmc',
#   'guidelines',
#   'assist',
#   'registered',
#   'manager',
#   'ensuring',
#   'adequate',
#   'supplies',
#   'medication',
#   'correct',
#   'storage',
#   'medication',
#   'policy',
#   'assist',
#   'serving',
#   'meals',
#   'domestic',
#   'duties',
#   'laundry',
#   'occasional',
#   'cleaning',
#   'deal',
#   'internal',
#   'external',
#   'communications',
#   'service',
#   'users',
#   'parties',
#   'ensure',
#   'documentation',
#   'date',
#   'recorded',
#   'accurately',
#   'maintain',
#   'records',
#   'care',
#   'plans',
#   'required',
#   'care',
#   'quality',
#   'commission',
#   'business',
#   'management',
#   'work',
#   'directors',
#   'independently',
#   'generate',
#   'enquiries',
#   'proactively',
#   'deal',
#   'members',
#   'public',
#   'care',
#   'medical',
#   'professionals',
#   'ensure',
#   'high',
#   'level',
#   'occupancy',
#   'rates',
#   'manage',
#   'working',
#   'knowledge',
#   'home',
#   'policies',
#   'procedures',
#   'ensure',
#   'maintained',
#   'times',
#   'promote',
#   'act',
#   'strictly',
#   'accordance',
#   'home',
#   'health',
#   'safety',
#   'policy',
#   'ensure',
#   'good',
#   'health',
#   'safety',
#   'practice',
#   'working',
#   'environment',
#   'comply',
#   'coshh',
#   'riddor',
#   'environmental',
#   'health',
#   'fire',
#   'regulations',
#   'care',
#   'standards',
#   'act',
#   'bring',
#   'directors',
#   'attention',
#   'item',
#   'health',
#   'safety',
#   'importance',
#   'concern',
#   'potentially',
#   'needing',
#   'prompt',
#   'action',
#   'depth',
#   'operational',
#   'knowledge',
#   'emergency',
#   'procedures',
#   'ensure',
#   'cascaded',
#   'staff',
#   'service',
#   'users',
#   'attend',
#   'staff',
#   'meetings',
#   'arranged',
#   'ensure',
#   'staff',
#   'informed',
#   'items',
#   'discussed',
#   'decisions',
#   'made',
#   'attend',
#   'hours',
#   'annum',
#   'compulsory',
#   'training',
#   'outlined',
#   'personal',
#   'development',
#   'plan',
#   'participate',
#   'regular',
#   'reviews',
#   'annual',
#   'appraisal',
#   'order',
#   'develop',
#   'training',
#   'relation',
#   'skills',
#   'knowledge',
#   'promote',
#   'good',
#   'home',
#   'times',
#   'cover',
#   'colleagues',
#   'duties',
#   'times',
#   'sickness',
#   'holidays',
#   'develop',
#   'share',
#   'ideas',
#   'improvement',
#   'practice',
#   'home',
#   'implement',
#   'change',
#   'sensitively',
#   'effectively',
#   'replenish',
#   'stocks',
#   'exercise',
#   'cost',
#   'stock',
#   'control',
#   'operate',
#   'guidelines',
#   'data',
#   'protection',
#   'act',
#   'ensure',
#   'total',
#   'confidentiality',
#   'staff',
#   'service',
#   'users',
#   'managing',
#   'people',
#   'assist',
#   'supervise',
#   'staff',
#   'training',
#   'responsible',
#   'covering',
#   'staff',
#   'absences',
#   'managing',
#   'disputes',
#   'ensure',
#   'staff',
#   'contribute',
#   'ability',
#   'efficient',
#   'running',
#   'home',
#   'high',
#   'standards',
#   'maintained',
#   'ensure',
#   'staff',
#   'qualifications',
#   'training',
#   'duties',
#   'perform',
#   'ensure',
#   'staff',
#   'monthly',
#   'reviews',
#   'annual',
#   'appraisal',
#   'company',
#   'policy',
#   'duties',
#   'addition',
#   'responsibilities',
#   'listed',
#   'perform',
#   'duties',
#   'required',
#   'home',
#   'management',
#   'senior',
#   'staff',
#   'consideration',
#   'skills',
#   'status',
#   'duties',
#   'note',
#   'expected',
#   'duties',
#   'carried',
#   'performed',
#   'spirit',
#   'cooperation',
#   'required',
#   'dedicated',
#   'efficient',
#   'team',
#   'prime',
#   'aim',
#   'make',
#   'service',
#   'user',
#   'stay',
#   'comfortable',
#   'enjoyable'],
#  ['kareplus',
#   'national',
#   'recently',
#   'secured',
#   'contract',
#   'supply',
#   'largest',
#   'uk',
#   'residential',
#   'elderly',
#   'care',
#   'nursing',
#   'organisations',
#   'recruiting',
#   'uk',
#   'geographical',
#   'areas',
#   'homes',
#   'cover',
#   'minimum',
#   'qualifications',
#   'registered',
#   'general',
#   'nurse',
#   'registered',
#   'mental',
#   'nursecurrently',
#   'registered',
#   'nmcresponsible',
#   'home',
#   'manageraims',
#   'post',
#   'ensure',
#   'high',
#   'standards',
#   'resident',
#   'family',
#   'care',
#   'maintained',
#   'times',
#   'direction',
#   'home',
#   'manager',
#   'maintain',
#   'motivate',
#   'professional',
#   'efficient',
#   'staff',
#   'exercise',
#   'leadership',
#   'part',
#   'nursing',
#   'team',
#   'maintain',
#   'homely',
#   'atmosphere',
#   'create',
#   'dignified',
#   'environment',
#   'ensure',
#   'standards',
#   'maintained',
#   'compliance',
#   'health',
#   'care',
#   'policy',
#   'health',
#   'authority',
#   'guidelines',
#   'functions',
#   'professional',
#   'administrative',
#   'managerial',
#   'personnel',
#   'education',
#   'training',
#   'professional',
#   'supervise',
#   'professional',
#   'work',
#   'staff',
#   'nursing',
#   'home',
#   'cooperation',
#   'home',
#   'manager',
#   'accordance',
#   'nmc',
#   'code',
#   'conductb',
#   'policy',
#   'procedure',
#   'manual',
#   'nursing',
#   'homec',
#   'employee',
#   'handbookd',
#   'company',
#   'health',
#   'safety',
#   'policyassess',
#   'plan',
#   'implement',
#   'evaluate',
#   'individualised',
#   'care',
#   'residents',
#   'ensure',
#   'treatments',
#   'carried',
#   'prescribed',
#   'follow',
#   'nursing',
#   'home',
#   'policy',
#   'respect',
#   'custody',
#   'administration',
#   'drugs',
#   'maintain',
#   'personal',
#   'contact',
#   'residents',
#   'relatives',
#   'visitors',
#   'enhance',
#   'residents',
#   'quality',
#   'life',
#   'good',
#   'standing',
#   'business',
#   'continually',
#   'update',
#   'knowledge',
#   'nursing',
#   'techniques',
#   'procedures',
#   'relevant',
#   'research',
#   'underpins',
#   'nursing',
#   'practice',
#   'participate',
#   'evaluation',
#   'review',
#   'policies',
#   'report',
#   'home',
#   'manager',
#   'matters',
#   'effect',
#   'policy',
#   'administrative',
#   'managerial',
#   'assist',
#   'home',
#   'manager',
#   'deputy',
#   'management',
#   'nursing',
#   'home',
#   'required',
#   'assist',
#   'planning',
#   'workloads',
#   'nursing',
#   'resources',
#   'effectively',
#   'assist',
#   'maintaining',
#   'stocks',
#   'stores',
#   'adequate',
#   'levels',
#   'mindful',
#   'economy',
#   'good',
#   'housekeeping',
#   'ensure',
#   'safe',
#   'care',
#   'custody',
#   'residents',
#   'property',
#   'accordance',
#   'nursing',
#   'home',
#   'policy',
#   'report',
#   'accident',
#   'incident',
#   'loss',
#   'theft',
#   'home',
#   'manager',
#   'complete',
#   'statements',
#   'promptly',
#   'ensure',
#   'accurate',
#   'nursing',
#   'records',
#   'maintained',
#   'accordance',
#   'agreed',
#   'policy',
#   'personnel',
#   'maintain',
#   'working',
#   'knowledge',
#   'health',
#   'safety',
#   'work',
#   'actthe',
#   'operational',
#   'policies',
#   'manualthe',
#   'employee',
#   'handbook',
#   'conditions',
#   'service',
#   'disciplinary',
#   'grievance',
#   'procedure',
#   'assist',
#   'orientation',
#   'staff',
#   'nursing',
#   'home',
#   'assist',
#   'supervision',
#   'assessment',
#   'junior',
#   'staff',
#   'education',
#   'traininga',
#   'attend',
#   'study',
#   'days',
#   'courses',
#   'prep',
#   'update',
#   'clinical',
#   'knowledge',
#   'skills',
#   'current',
#   'research',
#   'nursing',
#   'theories',
#   'participate',
#   'inservice',
#   'training',
#   'junior',
#   'members',
#   'staff',
#   'assist',
#   'orientation',
#   'programmes',
#   'care',
#   'staff',
#   'nursing',
#   'employees',
#   'participate',
#   'nvq',
#   'programme',
#   'care',
#   'assistants',
#   'call',
#   'permanent',
#   'services',
#   'recruitment',
#   'resource',
#   'team',
#   'hours',
#   'mobile',
#   'email',
#   'resourcerkareplus',
#   'uk',
#   'perm',
#   'managerkareplus',
#   'uk'],
#  ['ecommerce',
#   'country',
#   'manager',
#   'netherlands',
#   'client',
#   'fast',
#   'growing',
#   'specialist',
#   'online',
#   'retailer',
#   'seeking',
#   'recruit',
#   'ecommerce',
#   'country',
#   'manager',
#   'fluent',
#   'dutch',
#   'join',
#   'growing',
#   'team',
#   'london',
#   'role',
#   'main',
#   'responsibilities',
#   'include',
#   'target',
#   'market',
#   'drive',
#   'growth',
#   'strategically',
#   'dutch',
#   'market',
#   'responsible',
#   'sales',
#   'dutch',
#   'market',
#   'realization',
#   'pricing',
#   'strategy',
#   'dutch',
#   'market',
#   'regular',
#   'liaison',
#   'manufacturers',
#   'support',
#   'marketing',
#   'team',
#   'successful',
#   'candidate',
#   'speak',
#   'dutch',
#   'english',
#   'fluently',
#   'strong',
#   'business',
#   'development',
#   'background',
#   'ecommerce',
#   'candidate',
#   'strong',
#   'understanding',
#   'dutch',
#   'market',
#   'excellent',
#   'interpersonal',
#   'skills',
#   'good',
#   'organizational',
#   'skills',
#   'exceptional',
#   'eye',
#   'detail',
#   'hard',
#   'worker',
#   'candidate',
#   'mentality',
#   'excellent',
#   'analytical',
#   'skills',
#   'good',
#   'knowledge',
#   'ms',
#   'excel',
#   'graduate',
#   'caliber',
#   'preferably',
#   'mba',
#   'excellent',
#   'opportunity',
#   'join',
#   'growing',
#   'exciting',
#   'company',
#   'note',
#   'candidates',
#   'eligible',
#   'work',
#   'uk',
#   'fit',
#   'criteria',
#   'mentioned',
#   'relevant',
#   'experience',
#   'interested',
#   'opportunity',
#   'contact',
#   'michael',
#   'classen',
#   'euro',
#   'london',
#   'appointments',
#   'classeneurolondon',
#   'applying',
#   'euro',
#   'london',
#   'appointments',
#   "uk's",
#   'largest',
#   'independent',
#   'language',
#   'consultancy',
#   'aim',
#   'respond',
#   'promptly',
#   'application',
#   'due',
#   'high',
#   'level',
#   "cv's",
#   'receive',
#   'respond',
#   'applicants',
#   'profile',
#   'matches',
#   'clients',
#   'requirements',
#   'enquire',
#   'vacancies',
#   'visit',
#   'website',
#   'www',
#   'eurolondon'],
#  ['business',
#   'development',
#   'manager',
#   'leading',
#   'financial',
#   'lending',
#   'plccrawley',
#   'rh',
#   'pa',
#   'bonus',
#   'potentialthe',
#   'opportunity',
#   'market',
#   'leaders',
#   'home',
#   'collected',
#   'credit',
#   'today',
#   'economic',
#   'climate',
#   'businesses',
#   'growing',
#   'happy',
#   'fact',
#   'tough',
#   'times',
#   'people',
#   'trust',
#   'offer',
#   'financial',
#   'products',
#   'put',
#   'control',
#   'responsible',
#   'approach',
#   'lending',
#   'means',
#   'continue',
#   'sound',
#   'profitable',
#   'great',
#   'news',
#   'career',
#   'offers',
#   'stability',
#   'opportunity',
#   'business',
#   'development',
#   'manager',
#   'role',
#   'business',
#   'development',
#   'manager',
#   'll',
#   'monitor',
#   'provide',
#   'structured',
#   'support',
#   'group',
#   'selfemployed',
#   'agents',
#   'lend',
#   'collect',
#   'behalf',
#   'good',
#   'communication',
#   'analytical',
#   'motivational',
#   'skills',
#   'essential',
#   'll',
#   'visiting',
#   'customers',
#   'homes',
#   'responding',
#   'individual',
#   'naturally',
#   'ability',
#   'deal',
#   'variety',
#   'circumstances',
#   'management',
#   'information',
#   'decision',
#   'making',
#   'tool',
#   'plays',
#   'large',
#   'part',
#   'role',
#   'excel',
#   'skills',
#   'developed',
#   'don',
#   'worry',
#   'don',
#   'previous',
#   'experience',
#   'financial',
#   'services',
#   'sector',
#   'll',
#   'give',
#   'comprehensive',
#   'induction',
#   'expect',
#   'ongoing',
#   'management',
#   'development',
#   'programme',
#   'equip',
#   'skills',
#   'knowledge',
#   'role',
#   'varied',
#   'satisfying',
#   'succeed',
#   'hold',
#   'full',
#   'driving',
#   'licence',
#   'access',
#   'vehicle',
#   'work',
#   'return',
#   'll',
#   'offer',
#   'competitive',
#   'salary',
#   'package',
#   'bonus',
#   'days',
#   'holiday',
#   'pension',
#   'generous',
#   'mileage',
#   'allowance',
#   'candidates',
#   'provide',
#   'proof',
#   'eligibility',
#   'work',
#   'uk',
#   'requested',
#   'equal',
#   'opportunities',
# ...
#   'design',
#   'development',
#   'planning',
#   'excellent',
#   'verbal',
#   'written',
#   'communication',
#   'senior',
#   'highways',
#   'technician',
#   'hold',
#   'responsibilities',
#   'including',
#   'preparing',
#   'drawings',
#   'technical',
#   'reports',
#   'high',
#   'standard',
#   'obtain',
#   'data',
#   'local',
#   'authorities',
#   'visit',
#   'sites',
#   'alongside',
#   'providing',
#   'highway',
#   'junction',
#   'feasibility',
#   'designs',
#   'private',
#   'sector',
#   'developments',
#   'complete',
#   'traffic',
#   'flow',
#   'swept',
#   'path',
#   'analyses',
#   'whilst',
#   'working',
#   'set',
#   'industry',
#   'company',
#   'guidelines',
#   'hardworking',
#   'opportunities',
#   'senior',
#   'highways',
#   'technician',
#   'role',
#   'competitive',
#   'salary',
#   'benefits',
#   'package',
#   'offer',
#   'candidate',
#   'commutable',
#   'locations',
#   'include',
#   'greater',
#   'london',
#   'reading',
#   'uxbridge',
#   'watford',
#   'croydon',
#   'slough',
#   'luton',
#   'dartford',
#   'st',
#   'albans',
#   'interested',
#   'initial',
#   'noncommittal',
#   'discussion',
#   'vacancy',
#   'opportunities',
#   'environmental',
#   'sector',
#   'call',
#   'isabel',
#   'stephens',
#   'penguin',
#   'recruitment',
#   'alternatively',
#   'email',
#   'cv',
#   'll',
#   'call',
#   'back',
#   'emails',
#   'isabel',
#   'stephenspenguinrecruitment',
#   'uk'],
#  ['store',
#   'manager',
#   'stretford',
#   'ote',
#   'client',
#   'national',
#   'market',
#   'furniture',
#   'carpets',
#   'company',
#   'inspiring',
#   'people',
#   'create',
#   'beautiful',
#   'furniture',
#   'carpets',
#   'years',
#   'client',
#   'made',
#   'huge',
#   'strides',
#   'providing',
#   'general',
#   'public',
#   'fantastic',
#   'furniture',
#   'beds',
#   'carpets',
#   'wardrobes',
#   'great',
#   'quality',
#   'standard',
#   'product',
#   'target',
#   'top',
#   'end',
#   'market',
#   'expecting',
#   'customers',
#   'pay',
#   'premium',
#   'offer',
#   'continually',
#   'generating',
#   'repeat',
#   'business',
#   'providing',
#   'customers',
#   'complete',
#   'customer',
#   'experience',
#   'private',
#   'business',
#   'roots',
#   'lie',
#   'firmly',
#   'stable',
#   'workshop',
#   'began',
#   'stores',
#   'open',
#   'uk',
#   'gradually',
#   'expanding',
#   'operations',
#   'based',
#   'successful',
#   'trading',
#   'business',
#   'began',
#   'back',
#   'recent',
#   'growth',
#   'recruit',
#   'store',
#   'manager',
#   'order',
#   'maximize',
#   'sales',
#   'profit',
#   'developing',
#   'service',
#   'focused',
#   'culture',
#   'exceed',
#   'customers',
#   'role',
#   'store',
#   'manager',
#   'responsible',
#   'operations',
#   'store',
#   'complete',
#   'autonomy',
#   'recruitment',
#   'retention',
#   'sales',
#   'marketing',
#   'driving',
#   'profitable',
#   'sales',
#   'volumes',
#   'profit',
#   'margins',
#   'targeted',
#   'reviewing',
#   'performance',
#   'targets',
#   'ensure',
#   'action',
#   'meet',
#   'targets',
#   'maximizing',
#   'sales',
#   'opportunities',
#   'effectively',
#   'implement',
#   'develop',
#   'clear',
#   'performance',
#   'targets',
#   'motivate',
#   'enthuse',
#   'staff',
#   'achieve',
#   'leading',
#   'displaying',
#   'hands',
#   'management',
#   'role',
#   'visible',
#   'shop',
#   'floor',
#   'times',
#   'provide',
#   'customers',
#   'excellent',
#   'service',
#   'brand',
#   'demands',
#   'whilst',
#   'developing',
#   'training',
#   'staff',
#   'enhance',
#   'career',
#   'goals',
#   'experienced',
#   'store',
#   'manager',
#   'preferably',
#   'furniture',
#   'carpet',
#   'retail',
#   'background',
#   'management',
#   'level',
#   'determined',
#   'meet',
#   'customer',
#   'expectations',
#   'healthy',
#   'attitude',
#   'competition',
#   'whilst',
#   'showing',
#   'natural',
#   'leadership',
#   'skills',
#   'inspiring',
#   'people',
#   'leading',
#   'front',
#   'assume',
#   'accountability',
#   'teams',
#   'stores',
#   'performance',
#   'recognize',
#   'areas',
#   'development',
#   'enhance',
#   'stores',
#   'sales',
#   'communicate',
#   'concisely',
#   'levels',
#   'set',
#   'clear',
#   'objectives',
#   'team',
#   'order',
#   'aid',
#   'performance',
#   'selling',
#   'approach',
#   'patience',
#   'key',
#   'eye',
#   'details',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'storemanagerfurniturecarpets',
#   'job'],
#  ['apply',
#   'today',
#   'start',
#   'tomorrow',
#   'sales',
#   'money',
#   'career',
#   'immediately',
#   'people',
#   'start',
#   'experience',
#   'provide',
#   'successful',
#   'applicants',
#   'full',
#   'product',
#   'training',
#   'continuous',
#   'coaching',
#   'day',
#   'office',
#   'candidates',
#   'previous',
#   'experience',
#   'sales',
#   'customer',
#   'service',
#   'advertising',
#   'promotions',
#   'retail',
#   'call',
#   'centre',
#   'hospitality',
#   'marketing',
#   'opportunities',
#   'slow',
#   'hardworking',
#   'start',
#   'career',
#   'apply',
#   'appointment',
#   'week',
#   'average',
#   'earnings',
#   'apply',
#   'online',
#   'candidates',
#   'live',
#   'uk',
#   'plymouth',
#   'area',
#   'commute',
#   'plymouth',
#   'office',
#   'daily',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'applytodaystarttomorrownewsalesfor',
#   'job'],
#  ['main',
#   'purpose',
#   'job',
#   'perform',
#   'range',
#   'mechanical',
#   'assembly',
#   'hydraulic',
#   'installation',
#   'electrical',
#   'wiring',
#   'manufacturing',
#   'production',
#   'operations',
#   'required',
#   'quality',
#   'standard',
#   'cost',
#   'targets',
#   'main',
#   'tasks',
#   'job',
#   'efficient',
#   'correct',
#   'specification',
#   'mechanical',
#   'assembly',
#   'hydraulic',
#   'installation',
#   'electrical',
#   'wiring',
#   'fabrication',
#   'fitting',
#   'operations',
#   'linked',
#   'manufacture',
#   'service',
#   'repair',
#   'access',
#   'platforms',
#   'competent',
#   'build',
#   'inspection',
#   'stages',
#   'materials',
#   'full',
#   'compliance',
#   'iso',
#   'procedures',
#   'total',
#   'quality',
#   'focus',
#   'direct',
#   'indirect',
#   'stages',
#   'manufacturing',
#   'process',
#   'achieve',
#   'quality',
#   'product',
#   'aligned',
#   'customers',
#   'specification',
#   'expectations',
#   'effective',
#   'efficient',
#   'added',
#   'organisation',
#   'control',
#   'allocated',
#   'operations',
#   'full',
#   'flexibility',
#   'including',
#   'training',
#   'training',
#   'enable',
#   'manufacturing',
#   'operations',
#   'completed',
#   'company',
#   'compliance',
#   'health',
#   'safety',
#   'standards',
#   'flexibility',
#   'development',
#   'skills',
#   'complete',
#   'manufacturing',
#   'process',
#   'production',
#   'product',
#   'cells',
#   'maintaining',
#   'developing',
#   'accurate',
#   'systems',
#   'procedures',
#   'ensuring',
#   'engineering',
#   'masters',
#   'works',
#   'orders',
#   'accurately',
#   'reflect',
#   'approved',
#   'parts',
#   'consumed',
#   'identification',
#   'low',
#   'stock',
#   'shortages',
#   'maintain',
#   'high',
#   'standard',
#   'workplace',
#   'organisation',
#   'continuous',
#   'improvement',
#   'elimination',
#   'waste',
#   'lean',
#   'manufacturing',
#   'techniques',
#   'tools',
#   'working',
#   'team',
#   'achieve',
#   'customer',
#   'quality',
#   'delivery',
#   'cost',
#   'innovation',
#   'requirements',
#   'striving',
#   'meet',
#   'performance',
#   'requirements',
#   'accidents',
#   'incidents',
#   'internal',
#   'quality',
#   'defects',
#   'cell',
#   'productivity',
#   'utilisation',
#   'stock',
#   'accuracy',
#   'wip',
#   'flow',
#   'lineadherence',
#   'ensuring',
#   'company',
#   'procedures',
#   'complied',
#   'qualifications',
#   'experience',
#   'ideally',
#   'city',
#   'guilds',
#   'formal',
#   'mechanical',
#   'electrical',
#   'assembly',
#   'qualification',
#   'stable',
#   'proven',
#   'experience',
#   'previous',
#   'mechanical',
#   'electrical',
#   'role',
#   'considered',
#   'formal',
#   'qualifications',
#   'exist',
#   'proven',
#   'communicated',
#   'hands',
#   'experience',
#   'skills',
#   'manufacturing',
#   'practices',
#   'medium',
#   'heavy',
#   'engineering',
#   'assembly',
#   'hydraulic',
#   'installation',
#   'basic',
#   'wiring',
#   'achieve',
#   'strict',
#   'quality',
#   'standards',
#   'specifications',
#   'team',
#   'player',
#   'full',
#   'flexibility',
#   'availability',
#   'regular',
#   'overtime',
#   'working',
#   'business',
#   'demand',
#   'requires',
#   'performance',
#   'skilled',
#   'skilled',
#   'roles',
#   'tasks',
#   'ability',
#   'work',
#   'pressure',
#   'meet',
#   'deadlines',
#   'remuneration',
#   'role',
#   'offers',
#   'competitive',
#   'wage',
#   'rate',
#   'business',
#   'performance',
#   'bonus',
#   'healthcare',
#   'scheme',
#   'contributory',
#   'pension',
#   'life',
#   'insurance',
#   'holiday',
#   'allowance',
#   'scheme'],
#  ['sales',
#   'associate',
#   'hip',
#   'knee',
#   'orthopaedics',
#   'market',
#   'leading',
#   'innovative',
#   'medical',
#   'device',
#   'company',
#   'led',
#   'product',
#   'development',
#   'orthopaedic',
#   'spinal',
#   'orthopaedic',
#   'market',
#   'offices',
#   'world',
#   'listed',
#   'global',
#   'giant',
#   'offers',
#   'employees',
#   'career',
#   'progression',
#   'development',
#   'opportunities',
#   'london',
#   'basic',
#   'salary',
#   'bonus',
#   'commission',
#   'excellent',
#   'package',
#   'including',
#   'car',
#   'corporate',
#   'benefits',
#   'territory',
#   'manager',
#   'sales',
#   'representative',
#   'account',
#   'manager',
#   'business',
#   'development',
#   'manager',
#   'sales',
#   'specialist',
#   'oda',
#   'odp',
#   'clinical',
#   'advisor',
#   'pharmaceutical',
#   'sales',
#   'orthopaedics',
#   'spinal',
#   'orthopaedics',
#   'theatre',
#   'company',
#   'employees',
#   'worldwide',
#   'market',
#   'leader',
#   'medical',
#   'device',
#   'market',
#   'countries',
#   'fantastic',
#   'training',
#   'career',
#   'progression',
#   'opportunities',
#   'billion',
#   'euro',
#   'turnover',
#   'sales',
#   'focused',
#   'organisation',
#   'excellent',
#   'reputation',
#   'medical',
#   'urology',
#   'market',
#   'role',
#   'hip',
#   'knee',
#   'sales',
#   'associate',
#   'position',
#   'rare',
#   'exciting',
#   'opportunity',
#   'clinical',
#   'medical',
#   'sales',
#   'professionals',
#   'join',
#   'true',
#   'market',
#   'leader',
#   'working',
#   'integral',
#   'part',
#   'key',
#   'account',
#   'management',
#   'team',
#   'working',
#   'closely',
#   'business',
#   'development',
#   'manager',
#   'hip',
#   'knee',
#   'support',
#   'associate',
#   'manage',
#   'portfolio',
#   'hospital',
#   'based',
#   'customers',
#   'promote',
#   'range',
#   'orthopaedic',
#   'products',
#   'techniques',
#   'theatre',
#   'role',
#   'appointed',
#   'person',
#   'spend',
#   'considerable',
#   'time',
#   'scrub',
#   'environment',
#   'tasked',
#   'positioning',
#   'company',
#   'provider',
#   'choice',
#   'orthopaedic',
#   'products',
#   'moving',
#   'forward',
#   'role',
#   'offers',
#   'applicants',
#   'chance',
#   'clinical',
#   'skills',
#   'commercial',
#   'setting',
#   'move',
#   'true',
#   'sales',
#   'role',
#   'position',
#   'focused',
#   'heavily',
#   'providing',
#   'quality',
#   'clinical',
#   'education',
#   'orthopaedic',
#   'surgeons',
#   'theatre',
#   'support',
#   'staff',
#   'applicant',
#   'applicants',
#   'position',
#   'working',
#   'sales',
#   'clinical',
#   'position',
#   'applicants',
#   'working',
#   'territory',
#   'manager',
#   'sales',
#   'representative',
#   'account',
#   'manager',
#   'business',
#   'development',
#   'manager',
#   'sales',
#   'specialist',
#   'oda',
#   'odp',
#   'clinical',
#   'advisor',
#   'pharmaceutical',
#   'sales',
#   'important',
#   'ability',
#   'demonstrate',
#   'clinical',
#   'sales',
#   'aptitude',
#   'role',
#   'requires',
#   'individual',
#   'forge',
#   'strong',
#   'relationships',
#   'commercial',
#   'setting',
#   'demonstrate',
#   'equally',
#   'strong',
#   'clinical',
#   'knowledge',
#   'working',
#   'hospital',
#   'sales',
#   'join',
#   'company',
#   'success',
#   'highly',
#   'rewarded',
#   'excellent',
#   'route',
#   'exciting',
#   'medical',
#   'devices',
#   'sector',
#   'important',
#   'thing',
#   'applicants',
#   'wanting',
#   'apply',
#   'desire',
#   'earn',
#   'progress',
#   'hard',
#   'work',
#   'commitment',
#   'apply',
#   'exciting',
#   'opportunities',
#   'medical',
#   'devices',
#   'sales',
#   'market',
#   'apply',
#   'online',
#   'progress',
#   'sales',
#   'recruitment',
#   'specialist',
#   'sales',
#   'medical',
#   'recruitment',
#   'consultancy',
#   'dedicated',
#   'offering',
#   'client',
#   'applicants',
#   'alike',
#   'highest',
#   'levels',
#   'service',
#   'years',
#   'experience',
#   'recruitment',
#   'specialise',
#   'areas',
#   'work',
#   'nurse',
#   'advisers',
#   'clinical',
#   'specialists',
#   'theatre',
#   'sales',
#   'specialists',
#   'sales',
#   'executives',
#   'business',
#   'development',
#   'managers',
#   'team',
#   'leaders',
#   'sales',
#   'managers',
#   'sales',
#   'directors',
#   'sales',
#   'focused',
#   'roles',
#   'medical',
#   'sector',
#   'core',
#   'therapy',
#   'areas',
#   'include',
#   'vascular',
#   'endoscopy',
#   'urology',
#   'neurology',
#   'ent',
#   'infection',
#   'control',
#   'anaesthesia',
#   'blood',
#   'products',
#   'diathermy',
#   'infusion',
#   'orthopaedics',
#   'surgical',
#   'instruments',
#   'pct',
#   'primary',
#   'secondary',
#   'theatre',
#   'rehabilitation',
#   'products',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'salestarget',
#   'uk',
#   'jobseeking',
#   'medicalsalesexecutiveassociateorthopaedics',
#   'job'],
#  ['mobile',
#   'super',
#   'optometrist',
#   'required',
#   'join',
#   'uk',
#   'leading',
#   'providers',
#   'domiciliary',
#   'eye',
#   'care',
#   'cover',
#   'oxford',
#   'area',
#   'company',
#   'provide',
#   'eye',
#   'health',
#   'care',
#   'patients',
#   'unable',
#   'access',
#   'high',
#   'street',
#   'optical',
#   'services',
#   'eye',
#   'examination',
#   'role',
#   'mobile',
#   'optometrist',
#   'based',
#   'home',
#   'travel',
#   'appointments',
#   'mile',
#   'radius',
#   'travel',
#   'patients',
#   'houses',
#   'day',
#   'latest',
#   'portable',
#   'diagnostic',
#   'equipment',
#   'carry',
#   'eye',
#   'test',
#   'whilst',
#   'offering',
#   'excellent',
#   'dispensing',
#   'aftercare',
#   'service',
#   'patients',
#   'generally',
#   'unable',
#   'travel',
#   'opticians',
#   'due',
#   'illness',
#   'disability',
#   'treated',
#   'care',
#   'respect',
#   'position',
#   'suit',
#   'newly',
#   'qualified',
#   'optometrist',
#   'training',
#   'provided',
#   'experienced',
#   'optoms',
#   'candidate',
#   'honest',
#   'trustworthy',
#   'dependable',
#   'whilst',
#   'ensuring',
#   'maintain',
#   'excellent',
#   'level',
#   'eye',
#   'health',
#   'care',
#   'excellent',
#   'opportunity',
#   'competitive',
#   'salary',
#   'ote',
#   'excellent',
#   'bonus',
#   'scheme',
#   'place',
#   'working',
#   'days',
#   'flexible',
#   'choose',
#   'work',
#   'days',
#   'week',
#   'work',
#   'weekend',
#   'required',
#   'drive',
#   'company',
#   'car',
#   'provided',
#   'sat',
#   'nav',
#   'alongside',
#   'mobile',
#   'laptop',
#   'attend',
#   'appointments',
#   'efficiently',
#   'great',
#   'company',
#   'work',
#   'support',
#   'training',
#   'provided',
#   'needed',
#   'opportunity',
#   'interest',
#   'email',
#   'copy',
#   'cv',
#   'alternatively',
#   'call',
#   'information'],
#  ['title',
#   'field',
#   'sales',
#   'executive',
#   'office',
#   'supplies',
#   'solutions',
#   'area',
#   'nottingham',
#   'basic',
#   'pay',
#   'legend',
#   'ote',
#   'benefits',
#   'company',
#   'car',
#   'laptop',
#   'phone',
#   'role',
#   'field',
#   'sales',
#   'executive',
#   'light',
#   'sabre',
#   'training',
#   'reporting',
#   'obi',
#   'wan',
#   'promoting',
#   'full',
#   'range',
#   'office',
#   'supplies',
#   'office',
#   'furniture',
#   'sme',
#   'market',
#   'place',
#   'securing',
#   'business',
#   'geographical',
#   'area',
#   'generating',
#   'leads',
#   'cold',
#   'calling',
#   'door',
#   'knocking',
#   'space',
#   'hopping',
#   'pre',
#   'booked',
#   'appointments',
#   'role',
#   'business',
#   'focused',
#   'wanting',
#   'job',
#   'kick',
#   'back',
#   'relax',
#   'apply',
#   'accounts',
#   'won',
#   'role',
#   'progress',
#   'account',
#   'management',
#   'world',
#   'domination',
#   'person',
#   'field',
#   'sales',
#   'executive',
#   'possess',
#   'jedi',
#   'training',
#   'advantageous',
#   'candidates',
#   'years',
#   'field',
#   'sales',
#   'experience',
#   'selling',
#   'office',
#   'supplies',
#   'stationary',
#   'solutions',
#   'sell',
#   'levels',
#   'including',
#   'jedi',
#   'master',
#   'level',
#   'excellent',
#   'communication',
#   'presentation',
#   'skills',
#   'drive',
#   'enthusiasm',
#   'excel',
#   'career',
#   'extremely',
#   'target',
#   'driven',
#   'motivated',
#   'success',
#   'company',
#   'established',
#   'company',
#   'experiencing',
#   'rapid',
#   'growth',
#   'dark',
#   'side',
#   'office',
#   'supplies',
#   'sales',
#   'background',
#   'considered',
#   'role',
#   'room',
#   'argue',
#   'client',
#   'send',
#   'cv',
#   'tgrattongenesisassociates',
#   'uk',
#   'job',
#   'originally',
#   'posted',
#   'www',
#   'totaljobs',
#   'jobseeking',
#   'fieldsalesexecutive',
#   'job']]

# %% [markdown]
# #### Remove words based on document frequency and term frequency

# %%
# Function to remove words that appear once
def remove_appear_once(tokenized):
    words = list(chain.from_iterable(tokenized))
    term_fd = FreqDist(words) # Calculate term frequency

    # List of words that only appear once
    appear_once = term_fd.hapaxes()
    
    # Remove words that only appear once
    return [[word for word in article if word not in appear_once] for article in tokenized]

# %%
# Function to remove top 50 frequent words in document frequency
def remove_top_50(tokenized):
    words_2 = list(chain.from_iterable([set(article) for article in tokenized]))
    doc_fd = FreqDist(words_2)  # Compute document frequency for each unique word/type

    # List of top 50 words based on document frequency
    most_common_50 = list(map(lambda x: x[0],doc_fd.most_common(50)))
    
    # Remove top 50 words
    return [[word for word in article if word not in most_common_50] for article in tokenized]

# %%
# Remove top 50 document frequent words and words that appear once in descriptions
tokenize_articles = remove_appear_once(tokenize_articles)
tokenize_articles = remove_top_50(tokenize_articles)

# %%
# Remove top 50 document frequent words and words that appear once in titles
titles = remove_appear_once(titles)
titles = remove_top_50(titles)

# %% [markdown]
# #### Define default values for blank title post-processing

# %%
# Define a default value for blank titles post-processing
non_specified = 'non_specified'
for i in range(len(titles)):
    if len(titles[i]) == 0: # If the title is blank, give it a default value
        titles[i] = [non_specified] 
titles
# Out:
# [['bromley'],
#  ['fund', 'fund'],
#  ['non_specified'],
#  ['brokers'],
#  ['nurses'],
#  ['production'],
#  ['scrub'],
#  ['purchase', 'ledger', 'clerk', 'maternity'],
#  ['non_specified'],
#  ['non_specified'],
#  ['treasury'],
#  ['european', 'payroll'],
#  ['engineering', 'yorkshire'],
#  ['international'],
#  ['production'],
#  ['insurance'],
#  ['vehicle', 'car'],
#  ['marine', 'specialist', 'product'],
#  ['medical'],
#  ['optical'],
#  ['perm', 'unit', 'flexi'],
#  ['perm', 'bangor', 'flexi', 'ph', 'bangor'],
#  ['non_specified'],
#  ['leading', 'lending', 'plc'],
#  ['dynamics', 'ax'],
#  ['nursing'],
#  ['mental'],
#  ['nurses', 'needed'],
#  ['head', 'planning', 'analysis', 'permanent', 'contract'],
#  ['branch'],
#  ['professional', 'telesales'],
#  ['non_specified'],
#  ['non_specified'],
#  ['investment', 'bank'],
#  ['non_specified'],
#  ['telesales'],
#  ['electronic', 'fire', 'security', 'solutions'],
#  ['stress'],
#  ['cnc', 'machinist'],
#  ['treasury', 'cashier'],
#  ['nurses', 'nurses', 'band', 'northampton'],
#  ['non_specified'],
#  ['permanent', 'salaried', 'gp', 'required', 'kent'],
#  ['homecare'],
#  ['non_specified'],
#  ['french', 'payable', 'clerk'],
#  ['community'],
#  ['hardware', 'digital'],
#  ['contract', 'media'],
#  ['lead', 'planner'],
#  ['metal', 'expert'],
#  ['non_specified'],
#  ['carer'],
#  ['non_specified'],
#  ['claims', 'negotiator'],
#  ['non_specified'],
#  ['mobile', 'city'],
#  ['part', 'management'],
#  ['watford'],
#  ['non_specified'],
#  ['scheme'],
#  ['area'],
#  ['managers', 'client', 'managers'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['control', 'systems'],
#  ['asbestos', 'cad', 'asbestos'],
#  ['norwegian', 'speakers', 'needed'],
#  ['mobile', 'plant'],
#  ['developer'],
#  ['workers'],
#  ['european', 'german'],
#  ['non_specified'],
#  ['lead', 'generator'],
#  ['non_specified'],
#  ['non_specified'],
#  ['bristol', 'motor'],
#  ['kent', 'maidstone'],
#  ['toolmaker'],
#  ['non_specified'],
#  ['locum', 'physiotherapist'],
#  ['non_specified'],
#  ['power'],
#  ['management'],
#  ['catering'],
#  ['cnc', 'turner', 'miller'],
#  ['engineering', 'advisor'],
#  ['non_specified'],
#  ['mobile', 'payments'],
#  ['junior'],
#  ['stores'],
#  ['search', 'media', 'technology'],
#  ['residential'],
#  ['non_specified'],
#  ['compliance', 'policy'],
#  ['lead', 'largs', 'largs'],
#  ['international', 'german', 'market'],
#  ['maidstone'],
#  ['specialist'],
#  ['director'],
#  ['insurance'],
#  ['site'],
#  ['unit'],
#  ['pensions', 'month', 'contract'],
#  ['non_specified'],
#  ['payroll'],
#  ['regional'],
#  ['hardware', 'document', 'solutions'],
#  ['non_specified'],
#  ['non_specified'],
#  ['nurses', 'sussex'],
#  ['ifa'],
#  ['services', 'ote'],
#  ['installation'],
#  ['bias', 'shift'],
#  ['fitter'],
#  ['solidworks'],
#  ['marine', 'systems'],
#  ['hvac', 'building', 'services'],
#  ['optical'],
#  ['mobile', 'data', 'centre', 'reading'],
#  ['fmcg', 'global'],
#  ['cnc', 'programmer', 'setter', 'turner'],
#  ['electronic'],
#  ['environmental', 'bristol'],
#  ['thames', 'ote', 'uncapped'],
#  ['edition'],
#  ['emea'],
#  ['non_specified'],
#  ['engineers', 'embedded', 'defence'],
#  ['representative'],
#  ['non_specified'],
#  ['non_specified'],
#  ['european', 'bank'],
#  ['hvac', 'central', 'days'],
#  ['branch'],
#  ['gp', 'locum', 'term', 'locum'],
#  ['non_specified'],
#  ['non_specified'],
#  ['months', 'fixed', 'term', 'maternity'],
#  ['digital', 'advertising', 'experience'],
#  ['associate', 'geotechnical'],
#  ['workers', 'full', 'part'],
#  ['welder'],
#  ['associate', 'director', 'equity', 'car'],
#  ['pa', 'services'],
#  ['non_specified'],
#  ['digital', 'media'],
#  ['jobs', 'scotland'],
#  ['engineering'],
#  ['general'],
#  ['ote'],
#  ['principal'],
#  ['residential'],
#  ['nuclear', 'safety', 'specialist'],
#  ['buyer'],
#  ['non_specified'],
#  ['developer'],
#  ['applications'],
#  ['global', 'management'],
#  ['mobile', 'gas', 'reading'],
#  ['treasury'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['specialist'],
#  ['non_specified'],
#  ['nursing', 'managers', 'cardiff'],
#  ['group'],
#  ['carer', 'required'],
#  ['industrial'],
#  ['general'],
#  ['non_specified'],
#  ['compliance', 'payments', 'watford'],
#  ['band', 'specialist', 'paediatric'],
#  ['group', 'safety', 'environmental', 'quality', 'uk'],
#  ['company'],
#  ['shift'],
#  ['machine'],
#  ['non_specified'],
#  ['non_specified'],
#  ['quantity', 'surveyor', 'chichester', 'west', 'sussex'],
#  ['corporate'],
#  ['non_specified'],
#  ['customer', 'assurance'],
#  ['non_specified'],
#  ['non_specified'],
#  ['auditor', 'policy'],
#  ['bournemouth'],
#  ['compliance', 'monitoring'],
#  ['team', 'leader'],
#  ['director'],
#  ['non_specified'],
#  ['site', 'residential'],
#  ['non_specified'],
#  ['welder'],
#  ['non_specified'],
#  ['non_specified'],
#  ['associate', 'quantity', 'surveyor', 'residential'],
#  ['multiskilled', 'leading', 'manufacturing', 'group'],
#  ['trainee'],
#  ['head', 'compliance'],
#  ['non_specified'],
#  ['bookkeeper'],
#  ['social', 'occupational', 'therapist'],
#  ['non_specified'],
#  ['systems'],
#  ['job', 'tunbridge', 'wells'],
#  ['corporate'],
#  ['quality', 'inspector', 'quality', 'control', 'inspector'],
#  ['non_specified'],
#  ['quantity', 'surveyor'],
#  ['partnership', 'director'],
#  ['shift', 'fmcg'],
#  ['non_specified'],
#  ['electronics'],
#  ['multiskilled'],
#  ['non_specified'],
#  ['principal', 'naval', 'architect'],
#  ['client', 'technology', 'city'],
#  ['non_specified'],
#  ['advisor'],
#  ['non_specified'],
#  ['non_specified'],
#  ['digital', 'test'],
#  ['lead'],
#  ['non_specified'],
#  ['controls', 'automation', 'fmcg'],
#  ['contract', 'manufacturing'],
#  ['specialist'],
#  ['investment'],
#  ['credit', 'part'],
#  ['turner'],
#  ['job'],
#  ['non_specified'],
#  ['machine', 'construction', 'equipment', 'uncapped', 'ote'],
#  ['practice'],
#  ['telecoms'],
#  ['non_specified'],
#  ['general'],
#  ['manchester', 'ote'],
#  ['contract', 'ledger', 'clerk', 'full', 'perm'],
#  ['night', 'shift'],
#  ['embedded'],
#  ['manufacturing', 'operations', 'director', 'car'],
#  ['wholesale', 'birmingham'],
#  ['non_specified'],
#  ['vehicle', 'supervisor'],
#  ['non_specified'],
#  ['advertising'],
#  ['supervisor'],
#  ['geotechnical', 'derby'],
#  ['non_specified'],
#  ['db'],
#  ['general', 'jobs'],
#  ['non_specified'],
#  ['job', 'chichester'],
#  ['assistants'],
#  ['theatre'],
#  ['education'],
#  ['laundry', 'gloucester'],
#  ['non_specified'],
#  ['temp', 'perm'],
#  ['west', 'sussex'],
#  ['cnc', 'programmer', 'supervisor'],
#  ['reading'],
#  ['corporate'],
#  ['language', 'therapist', 'term'],
#  ['non_specified'],
#  ['non_specified'],
#  ['operations', 'aberdeen', 'global', 'company'],
#  ['regional'],
#  ['non_specified'],
#  ['allied', 'professional', 'optometrists', 'jobs', 'southampton'],
#  ['non_specified'],
#  ['net', 'developer'],
#  ['jobs', 'bromley'],
#  ['quality'],
#  ['ph'],
#  ['compliance', 'monitoring', 'officer'],
#  ['operations'],
#  ['engineers'],
#  ['data'],
#  ['toolmaker'],
#  ['barchester', 'healthcare'],
#  ['mental'],
#  ['machinist'],
#  ['non_specified'],
#  ['head'],
#  ['non_specified'],
#  ['days'],
#  ['electronics'],
#  ['edmonton', 'edmonton'],
#  ['legal', 'cashier'],
#  ['heating', 'uk'],
#  ['non_specified'],
#  ['non_specified'],
#  ['partnership'],
#  ['nights'],
#  ['team', 'leader', 'electronic', 'test', 'systems'],
#  ['medical'],
#  ['personal', 'tax'],
#  ['telesales', 'advisor'],
#  ['management', 'system'],
#  ['council', 'nursing', 'council'],
#  ['non_specified'],
#  ['non_specified'],
#  ['administration'],
#  ['non_specified'],
#  ['non_specified'],
#  ['motor', 'underwriter'],
#  ['carer'],
#  ['general'],
#  ['head', 'office'],
#  ['non_specified'],
#  ['cambridge'],
#  ['global', 'services'],
#  ['allied', 'professional', 'managers', 'jobs', 'kettering'],
#  ['quant', 'equity'],
#  ['months'],
#  ['validation', 'bias'],
#  ['non_specified'],
#  ['construction', 'products', 'surrey'],
#  ['lead'],
#  ['area'],
#  ['theatre', 'practitioner', 'scrub'],
#  ['customer', 'officer'],
#  ['non_specified'],
#  ['locum', 'shifts'],
#  ['non_specified'],
#  ['non_specified'],
#  ['fitter'],
#  ['portfolio'],
#  ['non_specified'],
#  ['non_specified'],
#  ['retail', 'expert'],
#  ['manufacturing'],
#  ['non_specified'],
#  ['policy'],
#  ['cad', 'packaging'],
#  ['quantity', 'surveyor'],
#  ['mortgage'],
#  ['fire', 'safety', 'operations'],
#  ['high', 'pressure', 'systems'],
#  ['marketing'],
#  ['services', 'administration', 'clerk'],
#  ['wholesale'],
#  ['territory'],
#  ['non_specified'],
#  ['telesales'],
#  ['contract', 'digital', 'test', 'electronics', 'surrey'],
#  ['non_specified'],
#  ['stores', 'manufacturing', 'yorkshire'],
#  ['principal', 'architect', 'cambridge'],
#  ['rnld'],
#  ['domiciliary', 'preston'],
#  ['retail'],
#  ['solutions'],
#  ['band', 'month', 'contracts'],
#  ['rnld'],
#  ['site'],
#  ['non_specified'],
#  ['hca', 'family', 'planning', 'surgery', 'part'],
#  ['non_specified'],
#  ['domiciliary'],
#  ['car', 'bristol'],
#  ['motor', 'team', 'leader'],
#  ['insurance'],
#  ['cnc', 'setter', 'programmer'],
#  ['compliance', 'officer'],
#  ['quantity', 'surveyor', 'quantity', 'surveyor'],
#  ['non_specified'],
#  ['non_specified'],
#  ['plc'],
#  ['non_specified'],
#  ['handler'],
#  ['workers', 'derby'],
#  ['pensions'],
#  ['supervisor'],
#  ['cad', 'aberdeen', 'ote'],
#  ['high', 'engineering'],
#  ['area', 'water'],
#  ['nursing'],
#  ['associate', 'director', 'emea'],
#  ['practice', 'medical'],
#  ['forklift'],
#  ['uk', 'global', 'lending'],
#  ['junior'],
#  ['non_specified'],
#  ['non_specified'],
#  ['representative', 'lead', 'generator'],
#  ['representative', 'construction', 'trainee', 'experienced'],
#  ['partner'],
#  ['occupational', 'physiotherapist', 'db', 'show', 'show'],
#  ['equipment'],
#  ['german'],
#  ['scotland'],
#  ['online', 'lead', 'specialist'],
#  ['part', 'payroll', 'clerk'],
#  ['inspector', 'metal'],
#  ['non_specified'],
#  ['fundraiser'],
#  ['experienced', 'machinist', 'borer', 'engineering'],
#  ['systems'],
#  ['catering', 'laundry', 'equipment'],
#  ['non_specified'],
#  ['band', 'central'],
#  ['test', 'validation'],
#  ['non_specified'],
#  ['bournemouth', 'bournemouth'],
#  ['non_specified'],
#  ['insurance', 'underwriter'],
#  ['payroll'],
#  ['packaging', 'marketing'],
#  ['non_specified'],
#  ['telesales'],
#  ['cad'],
#  ['non_specified'],
#  ['community', 'west'],
#  ['ote'],
#  ['ifa', 'client'],
#  ['independent'],
#  ['junior', 'corporate'],
#  ['non_specified'],
#  ['non_specified'],
#  ['officer'],
#  ['engineers', 'engineers'],
#  ['non_specified'],
#  ['healthcare', 'hca', 'band', 'southport', 'southport'],
#  ['quantity', 'surveyor'],
#  ['band', 'occupational', 'therapist'],
#  ['chichester'],
#  ['mobile', 'plant'],
#  ['non_specified'],
#  ['domiciliary', 'team', 'leader'],
#  ['underwriter'],
#  ['non_specified'],
#  ['job', 'nights'],
#  ['non_specified'],
#  ['kettering', 'kettering'],
#  ['engineering'],
#  ['non_specified'],
#  ['non_specified'],
#  ['operations'],
#  ['territory'],
#  ['non_specified'],
#  ['payable', 'team', 'leader', 'supervisor'],
#  ['engineering'],
#  ['barchester', 'healthcare'],
#  ['non_specified'],
#  ['non_specified'],
#  ['management'],
#  ['trainee'],
#  ['tunbridge', 'wells'],
#  ['non_specified'],
#  ['non_specified'],
#  ['derby'],
#  ['customer'],
#  ['paraplanner'],
#  ['representative'],
#  ['non_specified'],
#  ['non_specified'],
#  ['paediatric', 'healthcare', 'west'],
#  ['central', 'scotland'],
#  ['non_specified'],
#  ['corporate'],
#  ['trainee', 'telesales'],
#  ['non_specified'],
#  ['engineering', 'birmingham'],
#  ['non_specified'],
#  ['cambridge'],
#  ['non_specified'],
#  ['practice', 'north', 'yorkshire'],
#  ['independent'],
#  ['principal'],
#  ['non_specified'],
#  ['non_specified'],
#  ['european'],
#  ['plant', 'fitter', 'plant', 'engineers'],
#  ['salaried', 'gp', 'job'],
#  ['visual'],
#  ['team'],
#  ['non_specified'],
#  ['power'],
#  ['mortgage', 'services', 'uk', 'leading', 'estate'],
#  ['non_specified'],
#  ['jobs'],
#  ['education', 'birmingham'],
#  ['events', 'advisor'],
#  ['insurance'],
#  ['events', 'aberdeen', 'ote'],
#  ['developer'],
#  ['manufacturing'],
#  ['operations'],
#  ['optometrist'],
#  ['nursing'],
#  ['negotiator'],
#  ['rnld', 'night'],
#  ['welder', 'fabricator'],
#  ['telesales', 'operator', 'negotiator'],
#  ['underwriter'],
#  ['supervisor', 'domiciliary'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['stress'],
#  ['corporate', 'tax'],
#  ['job'],
#  ['optical', 'instrumentation', 'systems'],
#  ['forklift'],
#  ['product'],
#  ['bexhillonsea'],
#  ['non_specified'],
#  ['optometrist'],
#  ['assistants'],
#  ['non_specified'],
#  ['product'],
#  ['non_specified'],
#  ['northampton'],
#  ['general'],
#  ['non_specified'],
#  ['car'],
#  ['part'],
#  ['non_specified'],
#  ['preston'],
#  ['agency', 'healthcare', 'assistants', 'southport'],
#  ['search'],
#  ['non_specified'],
#  ['air', 'conditioning', 'edition'],
#  ['investment'],
#  ['locum', 'physiotherapist', 'intermediate', 'central'],
#  ['higher', 'level'],
#  ['system', 'products'],
#  ['non_specified'],
#  ['representative'],
#  ['mortgage'],
#  ['cnc', 'machinist', 'borer'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['car'],
#  ['chelmsford'],
#  ['non_specified'],
#  ['pa', 'partner'],
#  ['non_specified'],
#  ['fabricator', 'welder'],
#  ['chichester', 'area'],
#  ['surveyor', 'advisor'],
#  ['brokers', 'ote'],
#  ['regional', 'industrial', 'solutions'],
#  ['assurance', 'insurance'],
#  ['non_specified'],
#  ['community'],
#  ['non_specified'],
#  ['non_specified'],
#  ['estate', 'agency', 'negotiator'],
#  ['pressure'],
#  ['industrial'],
#  ['area', 'building', 'construction'],
#  ['nuclear', 'safety', 'engineers', 'gloucester'],
#  ['non_specified'],
#  ['norwegian', 'language', 'ledger', 'clerk'],
#  ['purchase', 'ledger', 'clerk'],
#  ['fmcg', 'manufacturing', 'group'],
#  ['market'],
#  ['non_specified'],
#  ['buyer'],
#  ['nursing'],
#  ['night', 'required', 'nursing'],
#  ['planner'],
#  ['non_specified'],
#  ['non_specified'],
#  ['quality', 'assurance'],
#  ['family'],
#  ['central'],
#  ['strategic'],
#  ['media'],
#  ['territory', 'medical'],
#  ['security'],
#  ['qualified', 'social'],
#  ['non_specified'],
#  ['fitter'],
#  ['assurance', 'services', 'controls', 'assurance', 'north'],
#  ['junior', 'intermediate', 'engineers'],
#  ['products'],
#  ['non_specified'],
#  ['norwegian', 'speakers', 'needed', 'urgently'],
#  ['representative'],
#  ['non_specified'],
#  ['company', 'office'],
#  ['bookkeeper'],
#  ['electrician'],
#  ['global', 'company'],
#  ['paraplanner', 'ndash', 'ndash', 'benefits'],
#  ['security', 'officer', 'higher', 'level'],
#  ['developer', 'net'],
#  ['treasury'],
#  ['water'],
#  ['non_specified'],
#  ['months', 'contract'],
#  ['non_specified'],
#  ['negotiator'],
#  ['agency'],
#  ['westonsupermare', 'westonsupermare'],
#  ['group'],
#  ['control', 'instrumentation'],
#  ['non_specified'],
#  ['test'],
#  ['non_specified'],
#  ['healthcare', 'hca'],
#  ['cnc', 'setter', 'operator'],
#  ['haslemere', 'haslemere'],
#  ['non_specified'],
#  ['non_specified'],
#  ['social', 'advisor', 'chelmsford'],
#  ['team'],
#  ['non_specified'],
#  ['director'],
#  ['treasury'],
#  ['general', 'surgery'],
#  ['night'],
#  ['mental'],
#  ['treasury'],
#  ['gas', 'fitter'],
#  ['contracts'],
#  ['trainee'],
#  ['non_specified'],
#  ['ph', 'preston', 'preston'],
#  ['non_specified'],
#  ['non_specified'],
#  ['pensions', 'administration', 'specialist'],
#  ['test', 'embedded'],
#  ['embedded', 'high'],
#  ['control', 'north', 'west'],
#  ['non_specified'],
#  ['dynamics', 'ax', 'yorkshire'],
#  ['band'],
#  ['director', 'online'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['branch', 'birmingham'],
#  ['homecare', 'manchester'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['fundraiser'],
#  ['contract', 'solidworks'],
#  ['part'],
#  ['fixed', 'portfolio'],
#  ['head'],
#  ['data', 'services'],
#  ['document'],
#  ['non_specified'],
#  ['credit', 'control'],
#  ['validation'],
#  ['credit'],
#  ['insurance'],
#  ['non_specified'],
#  ['heating'],
#  ['non_specified'],
#  ['air', 'conditioning'],
#  ['claims', 'handler'],
#  ['job'],
#  ['scheme', 'operations'],
#  ['social', 'workers'],
#  ['legal'],
#  ['manufacturing', 'quality', 'electronics'],
#  ['quant'],
#  ['advisor', 'credit', 'management'],
#  ['non_specified'],
#  ['ashford', 'ashford'],
#  ['systems', 'defence'],
#  ['southampton'],
#  ['electronics', 'product'],
#  ['non_specified'],
#  ['non_specified'],
#  ['territory', 'west'],
#  ['non_specified'],
#  ['quality'],
#  ['non_specified'],
#  ['applications'],
#  ['optometrists', 'jobs'],
#  ['temp', 'test'],
#  ['non_specified'],
#  ['team', 'leader'],
#  ['area', 'representative', 'area'],
#  ['non_specified'],
#  ['non_specified'],
#  ['machine', 'production'],
#  ['qualified', 'social'],
#  ['cnc', 'miller'],
#  ['electronics', 'hardware', 'digital'],
#  ['emea'],
#  ['director', 'strategic'],
#  ['mortgage'],
#  ['personal', 'auditor'],
#  ['non_specified'],
#  ['market', 'liquidity'],
#  ['fitter'],
#  ['control', 'systems', 'commissioning'],
#  ['tax'],
#  ['non_specified'],
#  ['children', 'nurses', 'experience', 'urgently', 'needed', 'thames'],
#  ['children'],
#  ['office'],
#  ['group', 'controls'],
#  ['non_specified'],
#  ['occupational', 'therapist'],
#  ['legal', 'control', 'product', 'analysis'],
#  ['north'],
#  ['credit'],
#  ['electrician'],
#  ['non_specified'],
#  ['telecoms'],
#  ['bexhillonsea'],
#  ['developer', 'visual'],
#  ['quality', 'compliance', 'part'],
#  ['plant'],
#  ['installation', 'commissioning', 'naval'],
#  ['power'],
#  ['non_specified'],
#  ['non_specified'],
#  ['advisor'],
#  ['junior'],
#  ['non_specified'],
#  ['non_specified'],
#  ['advisor'],
#  ['mental'],
#  ['theatre', 'practitioner', 'chichester'],
#  ['non_specified'],
#  ['non_specified'],
#  ['non_specified'],
#  ['media'],
#  ['non_specified'],
#  ['cardiff'],
#  ['area', 'representative'],
#  ['non_specified'],
#  ['controls', 'automation'],
#  ['shift', 'shift'],
#  ['locum', 'physiotherapist'],
#  ['purchase', 'language'],
#  ['non_specified'],
#  ['accounting'],
#  ['liquidity'],
#  ['general', 'birmingham'],
#  ['head', 'services'],
#  ['digital'],
#  ['management'],
#  ['accounting'],
#  ['associate'],
#  ['non_specified'],
#  ['french', 'german'],
#  ['associate'],
#  ['claims', 'inspector'],
#  ['community'],
#  ['nursing', 'thetford', 'thetford'],
#  ['non_specified'],
#  ['non_specified'],
#  ['trainee', 'birmingham', 'city', 'centre'],
#  ['birmingham'],
#  ['practitioner', 'required', 'locum', 'shifts'],
#  ['pensions', 'payroll'],
#  ['required', 'maidstone', 'kent'],
#  ['media', 'solutions'],
#  ['machinist'],
#  ['marketing'],
#  ['non_specified'],
#  ['benefits'],
#  ['non_specified'],
#  ['non_specified'],
#  ['production'],
#  ['medical', 'associate'],
#  ['mobile', 'optometrist'],
#  ['non_specified']]

# %% [markdown]
# ## Saving required outputs

# %%
# Function to write content to file
def write_to_file(filename, content):
    out_file = open(filename, 'w') # Open file
    out_file.write(content) # Write content to file
    out_file.close() # Close file

# %% [markdown]
# - #### vocab.txt

# %%
# Sort the vocabulary alphabetically
vocab = sorted(list(set(list(chain.from_iterable(tokenize_articles)))))
# Formatting description into a vocabulary to write to a file
vocab_s = '\n'.join(f"{(vocab)[c]}:{c}" for c in range(len((vocab))))

# %%
# Save vocabulary in vocab.txt
write_to_file('vocab.txt', vocab_s)

# %% [markdown]
# - #### preprocessed.txt

# %%
# Formatting preprocessed descriptions into a string to write to a file
preprocessed_s = '\n'.join(' '.join(article) for article in tokenize_articles)

# %%
# Save preprocessed descriptions in preprocessed.txt
write_to_file('preprocessed.txt', preprocessed_s)

# %% [markdown]
# - #### web_indexes.txt

# %%
# Formatting webindexes into a string to write to a file
web_indexes_s = '\n'.join(web_indexes)

# %%
# Save webindexes in webindexes.txt
write_to_file('web_indexes.txt', web_indexes_s)

# %% [markdown]
# - #### titles.txt

# %%
# Formatting titles into a string to write to a file
titles_s = '\n'.join(' '.join(title) for title in titles)

# %%
# Save titles in titles.txt
write_to_file('titles.txt', titles_s)

# %% [markdown]
# ## Summary
# Give a short summary and anything you would like to talk about the assessment task here.

# %% [markdown]
# ## Couple of notes for all code blocks in this notebook
# - please provide proper comment on your code
# - Please re-start and run all cells to make sure codes are runable and include your output in the submission.
